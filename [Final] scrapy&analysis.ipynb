# %% [markdown]
# ### Youtube 댓글 크롤링 & 분석(검색어: 타다 금지법)

# %% [markdown]
# #### 1. 크롤링 대상: 이번달에 '타다 금지법'으로 업로드 된 동영상
# #### - 데이터: 사용자 id, 댓글, 좋아요 수

# %%
#유튜브 첫 화면
from PIL import Image as pil
main_page = pil.open("youtube/month.png")
main_page
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1098x565 at 0x7FC08C7E00F0>

# %%
# 상세 화면(최근 날짜 순으로 정렬 후 댓글 가져오기)
page = pil.open("youtube/page.png")
page
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=674x532 at 0x7FC08B07F390>

# %% [markdown]
# ### 2. Scrapy Code

# %% [markdown]
# #### 1) 프로젝트 생성

# %%
# !rm -rf youtube/

# %%
# !scrapy startproject youtube

# %% [markdown]
# #### 2) items.py 작성

# %%
# !cat youtube/youtube/items.py

# %%
# %%writefile youtube/youtube/items.py

import scrapy

class YoutubeItem(scrapy.Item):
    title = scrapy.Field()
    user_id = scrapy.Field()
    comment = scrapy.Field()
    like_num = scrapy.Field()
    link = scrapy.Field()
# Out:
# Overwriting youtube/youtube/items.py

# %% [markdown]
# #### 3) spider.py 작성

# %%
# %%writefile youtube/youtube/spiders/spider.py

import requests
import time
import scrapy

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from scrapy.http import TextResponse
from bs4 import BeautifulSoup
from youtube.items import YoutubeItem
from scrapy.spiders import Spider

class YoutubeCrawler(scrapy.Spider):
    item = YoutubeItem()
    name = "YoutubeCrawler"   
    allow_domains = ["youtube.com"]
    start_urls = ['https://www.youtube.com/results?search_query=타다 금지법&sp=EgYIBBABGAE%253D']
       
    def __init__(self):
        scrapy.Spider.__init__(self)
        options = Options()
        options.headless = True
        self.driver = webdriver.Chrome('/home/ubuntu/chromedriver', options=options)
        
    def parse(self, response):
        self.driver.get(response.url)
    
        time.sleep(2)
        page=self.driver.page_source

        soup = BeautifulSoup(page,'lxml')
        all_ = soup.find_all('a','yt-simple-endpoint style-scope ytd-video-renderer')
        
        #유튜브 첫 화면에서 이번달 업로드된 동영상 링크
        links= ["https://www.youtube.com/" + all_[n].get('href') for n in range(0,len(all_))]
        
        for link in links:
            yield scrapy.Request(link, callback=self.get_content)
        
    def get_content(self, response): #세부 링크 response
        time.sleep(10)
        self.driver.get(response.url)
        
        #모든 댓글 가져오기 위해, 페이지 스크롤 끝까지 내리기
        body = self.driver.find_element_by_tag_name("body")
        
        num_of_pagedowns = 30
        
        last_page_height = self.driver.execute_script("return document.documentElement.scrollHeight")

        while True: 
            self.driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);") 
            time.sleep(10.0) 
            new_page_height = self.driver.execute_script("return document.documentElement.scrollHeight") 
            
            if new_page_height == last_page_height: 
                break 
            
            last_page_height = new_page_height

        #댓글: 최근 날짜 순으로 정렬
            try: 
                self.driver.find_element_by_xpath('//*[@id="sort-menu"]').click() 
                self.driver.find_element_by_xpath('//*[@id="menu"]/a[2]/paper-item/paper-item-body/div[text()="최근 날짜순"]').click() 
        
            except Exception as e: 
                pass       
        
            #제목
            title = self.driver.find_element_by_css_selector('#container > h1 > yt-formatted-string').text
            #사용자 id    
            user_ids = self.driver.find_elements_by_css_selector('#author-text > span')
            #댓글
            comments = self.driver.find_elements_by_css_selector('#content-text')
            #좋아요 수
            like_nums = self.driver.find_elements_by_css_selector('#vote-count-middle')
            
        for j in range(0, len(comments)):    
            item = YoutubeItem()
            item["title"] = title
            item["comment"] = comments[j].text
            item["user_id"] = user_ids[j].text
            item["like_num"] = like_nums[j].text
            item["link"] = response.url
            
            yield item
# Out:
# Overwriting youtube/youtube/spiders/spider.py

# %%
# %%writefile run.sh
# cd youtube
# scrapy crawl YoutubeCrawler -o YoutubeCrawling.csv
# Out:
# Overwriting run.sh

# %%
# !./run.sh

# %% [markdown]
# #### 4) pipeline.py 설정(pymongo 연결)

# %%
# %%writefile youtube/youtube/mongodb.py 

import pymongo

client = pymongo.MongoClient('mongodb://ip:ip@ip.ip.ip.ip:ip')

db = client.youtube
collection = db.result2
# Out:
# Overwriting youtube/youtube/mongodb.py

# %%
# !cat youtube/youtube/pipelines.py
# Out:
# import json
# import requests
# from .mongodb import collection
#
# from .mongodb import collection
#
# class YoutubePipeline(object):
#
#     def process_item(self, item, spider):
#         data = {"title": item["title"],
#                 "user_id": item["user_id"],
#                 "comment": item["comment"],
#                 "like_num" : item["like_num"],
#                 "link": item["link"]}
#         collection.insert(data)
#
#         return item

# %%
# %%writefile youtube/youtube/pipelines.py

from .mongodb import collection

class YoutubePipeline(object):

    def process_item(self, item, spider):
        data = {"title": item["title"], 
                "user_id": item["user_id"], 
                "comment": item["comment"], 
                "like_num" : item["like_num"]}
        collection.insert(data)

        return item
# Out:
# Overwriting youtube/youtube/pipelines.py

# %%
# 몽고 db 저장 결과
page = pil.open("youtube/mongodb.png")
page
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1914x455 at 0x7FC08B07F4A8>

# %%
# settings.py 파일 수정
#ITEM_PIPELINES = {
    #'naver_article.pipelines.NaverArticlePipeline': 300,
#}

# %%
#!./run.sh
# Out:
# 2020-03-17 20:43:03 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: youtube)
# 2020-03-17 20:43:03 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.6.9 (default, Jan 20 2020, 02:55:31) - [GCC 7.4.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-1060-aws-x86_64-with-debian-buster-sid
# 2020-03-17 20:43:03 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'youtube', 'FEED_FORMAT': 'csv', 'FEED_URI': 'YoutubeCrawling.csv', 'NEWSPIDER_MODULE': 'youtube.spiders', 'SPIDER_MODULES': ['youtube.spiders']}
# 2020-03-17 20:43:03 [scrapy.extensions.telnet] INFO: Telnet Password: 1112710ccb8e33f4
# 2020-03-17 20:43:03 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-03-17 20:43:04 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session {"capabilities": {"firstMatch": [{}], "alwaysMatch": {"browserName": "chrome", "platformName": "any", "goog:chromeOptions": {"extensions": [], "args": ["--headless"]}}}, "desiredCapabilities": {"browserName": "chrome", "version": "", "platform": "ANY", "goog:chromeOptions": {"extensions": [], "args": ["--headless"]}}}
# 2020-03-17 20:43:04 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): 127.0.0.1:35917
# 2020-03-17 20:43:05 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /
[urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/element/5b4841d2-e0f2-4dc6-9c61-e647854585cf/value HTTP/1.1" 200 14
# 2020-03-17 21:00:43 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:48 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element {"using": "xpath", "value": "//*[@id=\"sort-menu\"]"}
# 2020-03-17 21:00:48 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/element HTTP/1.1" 200 88
# 2020-03-17 21:00:48 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:48 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element/38cbfac6-fdb4-4a27-bd7b-c3c4253189a7/click {"id": "38cbfac6-fdb4-4a27-bd7b-c3c4253189a7"}
# 2020-03-17 21:00:49 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/element/38cbfac6-fdb4-4a27-bd7b-c3c4253189a7/click HTTP/1.1" 400 441
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element {"using": "css selector", "value": "#container > h1 > yt-formatted-string"}
# 2020-03-17 21:00:49 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/element HTTP/1.1" 200 88
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: GET http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element/c811d50c-8dda-42a6-96b4-7c45f2a51171/text {"id": "c811d50c-8dda-42a6-96b4-7c45f2a51171"}
# 2020-03-17 21:00:49 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "GET /session/7aea8fbda1564c1c03e79a0212a7f985/element/c811d50c-8dda-42a6-96b4-7c45f2a51171/text HTTP/1.1" 200 98
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/elements {"using": "css selector", "value": "#author-text > span"}
# 2020-03-17 21:00:49 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/elements HTTP/1.1" 200 485
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/elements {"using": "css selector", "value": "#content-text"}
# 2020-03-17 21:00:49 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/elements HTTP/1.1" 200 485
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/elements {"using": "css selector", "value": "#vote-count-middle"}
# 2020-03-17 21:00:49 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/elements HTTP/1.1" 200 485
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: GET http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element/133b8f21-1669-495c-bc4f-9932574af894/text {"id": "133b8f21-1669-495c-bc4f-9932574af894"}
# 2020-03-17 21:00:49 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "GET /session/7aea8fbda1564c1c03e79a0212a7f985/element/133b8f21-1669-495c-bc4f-9932574af894/text HTTP/1.1" 200 81
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: GET http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element/b95fc4b7-72a0-45be-9eba-09587e8d7b39/text {"id": "b95fc4b7-72a0-45be-9eba-09587e8d7b39"}
# 2020-03-17 21:00:49 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "GET /session/7aea8fbda1564c1c03e79a0212a7f985/element/b95fc4b7-72a0-45be-9eba-09587e8d7b39/text HTTP/1.1" 200 18
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: GET http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element/6f66e1ee-2e6a-4657-a266-20ffc0224762/text {"id": "6f66e1ee-2e6a-4657-a266-20ffc0224762"}
# 2020-03-17 21:00:49 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "GET /session/7aea8fbda1564c1c03e79a0212a7f985/element/6f66e1ee-2e6a-4657-a266-20ffc0224762/text HTTP/1.1" 200 13
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.youtube.com//watch?v=lZ-Tx8U3z0w>
# {'comment': '여객운수사업법 개정안 이지\n타다 금지법이 아니고',
#  'like_num': '2',
#  'link': 'https://www.youtube.com//watch?v=lZ-Tx8U3z0w',
#  'title': '이인영 사과…오늘 본회의 ‘타다금지법’ 등 처리 / KBS뉴스(News)',
#  'user_id': '윤석'}
# 2020-03-17 21:00:49 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/url {"url": "https://www.youtube.com//watch?v=kFXyeT2Kgig"}
# 2020-03-17 21:00:50 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/url HTTP/1.1" 200 14
# 2020-03-17 21:00:50 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:55 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element {"using": "css selector", "value": "body"}
# 2020-03-17 21:00:55 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/element HTTP/1.1" 200 88
# 2020-03-17 21:00:55 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:00:55 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element/26127f64-3513-4a56-9a02-f4b6cd24bf18/value {"text": "\ue00f", "value": ["\ue00f"], "id": "26127f64-3513-4a56-9a02-f4b6cd24bf18"}
# 2020-03-17 21:00:56 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/element/26127f64-3513-4a56-9a02-f4b6cd24bf18/value HTTP/1.1" 200 14
# 2020-03-17 21:00:56 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:01:01 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element {"using": "xpath", "value": "//*[@id=\"sort-menu\"]"}
# 2020-03-17 21:01:01 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/element HTTP/1.1" 404 254
# 2020-03-17 21:01:01 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:01:01 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element/26127f64-3513-4a56-9a02-f4b6cd24bf18/value {"text": "\ue00f", "value": ["\ue00f"], "id": "26127f64-3513-4a56-9a02-f4b6cd24bf18"}
# 2020-03-17 21:01:01 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/element/26127f64-3513-4a56-9a02-f4b6cd24bf18/value HTTP/1.1" 200 14
# 2020-03-17 21:01:01 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:01:06 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element {"using": "xpath", "value": "//*[@id=\"sort-menu\"]"}
# 2020-03-17 21:01:06 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/element HTTP/1.1" 404 254
# 2020-03-17 21:01:06 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:01:06 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element/26127f64-3513-4a56-9a02-f4b6cd24bf18/value {"text": "\ue00f", "value": ["\ue00f"], "id": "26127f64-3513-4a56-9a02-f4b6cd24bf18"}
# 2020-03-17 21:01:06 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/element/26127f64-3513-4a56-9a02-f4b6cd24bf18/value HTTP/1.1" 200 14
# 2020-03-17 21:01:06 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:01:11 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element {"using": "xpath", "value": "//*[@id=\"sort-menu\"]"}
# 2020-03-17 21:01:11 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/element HTTP/1.1" 404 254
# 2020-03-17 21:01:11 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-03-17 21:01:11 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:35917/session/7aea8fbda1564c1c03e79a0212a7f985/element/26127f64-3513-4a56-9a02-f4b6cd24bf18/value {"text": "\ue00f", "value": ["\ue00f"], "id": "26127f64-3513-4a56-9a02-f4b6cd24bf18"}
# 2020-03-17 21:01:11 [urllib3.connectionpool] DEBUG: http://127.0.0.1:35917 "POST /session/7aea8fbda1564c1c03e79a0212a7f985/element/26127f64-3513-4a56-9a02-f4b6cd24bf18/value HTTP/1.1" 200 14
# 2020-03-17 21:01:11 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request

# %% [markdown]
# ## 3. 댓글 분석

# %%
# koNLPy: 한국어 자연어 처리 패키지

from konlpy.tag import *  
from wordcloud import WordCloud

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

from collections import Counter 
import pandas as pd

import pymongo
import sys

okt = Okt()
kkma = Kkma()

# %%
#몽고 DB에서 크롤링한 데이터 불러오기
client = pymongo.MongoClient("mongodb://ip:ip@ip.ip.ip.ip:ip")
result = client.crawling.youtube
comment_result = pd.DataFrame(result.find({}))
comment_result.tail()
# Out:
#                            _id  \
# 1279  5e6f9a43899b7f0e360b8f25
# 1280  5e6f9a43899b7f0e360b8f26
# 1281  5e6f9a43899b7f0e360b8f27
# 1282  5e6f9a43899b7f0e360b8f28
# 1283  5e6f9a43899b7f0e360b8f29
#
#                                                 comment like_num  \
# 1279          타다 유권자 보단 택시 유권자가 많으니.. 표를 얻으려면 어쩔수 없지...       1개
# 1280  불법 타다 옹호하는 애들아! \n택시가 그렇게 불편하고 서비스가 엉망이면 서비스가 ...       3개
# 1281  타다 패. 카카오 회사 승.\n타다 금지법 통과 됐다고 해서 택시가 이기는게 아님....       1개
# 1282                             꽁으로 먹으려다 결국 이렇게 되었넹...       0개
# 1283                       사납금에 대해선 찍소리도 못하는 무식한 택시기사들.       1개
#
#                                     title youtube_id
# 1279  '타다 베이직' 4월 11일 중단…1만명 넘는 드라이버 어쩌나       김수면TV
# 1280  '타다 베이직' 4월 11일 중단…1만명 넘는 드라이버 어쩌나         김건이
# 1281  '타다 베이직' 4월 11일 중단…1만명 넘는 드라이버 어쩌나         김건이
# 1282  '타다 베이직' 4월 11일 중단…1만명 넘는 드라이버 어쩌나     subinoh
# 1283  '타다 베이직' 4월 11일 중단…1만명 넘는 드라이버 어쩌나    민주국가대한민국

# %%
# like_num에서 '개' 단어 제거
a = comment_result['like_num']
b=[]
for i in range(0, len(a)):
    c = a[i].replace("개","")
    b.append(c)

len(b)
# Out:
# 1284

# %%
#단어 연관성 분석 위해, 좋아요 수 많은 순으로 정렬
comment_result['like_co'] = b
comment_result['like_co'] = comment_result['like_co'].astype(int)
liek_co_up = comment_result.like_co >=1
comment_result_sort = comment_result.loc[liek_co_up, :]
comment_result_sort = comment_result_sort.sort_values(by='like_co', ascending=False)
comment_result_sort.head()
comment_sort = list(comment_result_sort['comment'])

# %%
comment_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 6 columns):
# _id           1284 non-null object
# comment       1284 non-null object
# like_num      1284 non-null object
# title         1284 non-null object
# youtube_id    1284 non-null object
# like_co       1284 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 60.3+ KB

# %%
# 500개의 댓글만 추출
comment = list(comment_result['comment'])
comment_sample = comment[0:500]
comment_sample
# Out:
# ['멍청한인간!대통령 등에업고 별 회괴한 짓거리를 다하는구나.노블리스오블리제!넌 도덕심도 양심도 없는 한낫 돈많은 괴물이야~',
#  '법앞에는 만인이 평등한걸 알아아지...권력기생충들...',
#  '혁신 ㅡ 지금도 택시회사나\n개인택시 ㅡ줄도산 위기 ㅡ\n타다 ㅡ 머여 ㅡ 자가용영업까지 한다고 ? ㅡ\n같이 죽자고  ?',
#  '이재용 대표님에게 한 말씀 하겠습니다 그렇게 운수업을 하고 싶으면 지금 당장택시 회사나 개인택시면허을 사 가지고 그렇게정상적으로 운영을 하세요 왜 돈 한푼 안 들이고 그렇게 공짜로 하려고 그러니까 반발이 심한거 아닙니까~\n이재용대표님에목적은다른대있는거다압니다',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '당연한거다 어디서 말장난으로 사가지없이',
#  '수천 수만대 택시가 대기\n중 인대\n계속 대기 하고 있을까\n타다 당신도 번호판 4차\n5차 하면',
#  "택시 서비스개선 수칙!\n나는 내 택시를 이용하는 승객에게 내가 이용한다는 생각으로 반대의 입장에서 운행한다!!\n\n1.내 영업구역 외 가급적 합법 승차거부도 줄인다\n2.내 택시는 항상 청결을 유지한다\n3.익숙하진 않지만 '안녕하세요','감사합니다 '\n   최대한 웃는 얼굴로 승객을 대한다\n4.승객의 짐은 내가 싣고 내려 드린다\n5.인사말 외 최대한 말을 줄인다\n6.카드 계산도 반갑게 받아 들인다\n7.내 택시가 운행할 수 있는 도로는 무조건\n   모신다\n8.절대 운행 중 전화는 사양한다\n9.과속및 난폭운전 NO 준법운행 한다\n10.용모단정!\n11.절대 영업구역 내 승차거부는 없다\n12.젊은 승객에게 반말하지 않기\n\n등등 수칙으로 정할 사항이 더 있을 듯 합니다\n택시 서비스개선만이 답임을 동참 해 나가시죠\n동료 선,후배님들 이제부터 시작입니다!\n우리 업권보호를 위한 모습!!파이팅입니다",
#  'it하나 접목시킨거 빼고는 택시랑 다를게 없는데 워가 혁신이라는거지?',
#  '택시 평점제 도입 국민청원. 아래 링크',
#  '대한민국 자우시장국가맞지? ㅋㅋㅋ 택시만 경쟁하는 모습 ㅈ같노 ㅋㅋ',
#  '불법스타트업은안생겨도이세상아주잘돌아가.그런걱정은안해도돼.세계평화나잘연구해봐',
#  '멍멍이 소리 하지 마시고\n법 안으로 들어와\n날로 먹지 말고',
#  '타다가 스타트 업이래... 이재웅아 사기치지 마라.',
#  '택시도 너무  많아서   다 서있는데',
#  '진짜 진보적이지 못하네 ..',
#  '불법 타다야 잘 가라!!!',
#  '민주주의의 후퇴! 부끄럽다.',
#  '렌터카 타다가 택시영업하면 안되지...',
#  '이재웅ㄲㆍ시다',
#  '타다차량이1500대인데 기사가 10000명이면 차한대당 10명한달에 한분에기사가 3일씩나누어서 주말빼고 일하는계산이나오는데 3일 일하고 생계가 걱정  입만열면 구라야',
#  '타다 1500대인데 기사가 12000명 이면 차한대에 기사가 10명정도 라는 말인데요 말이 안맞아 웃기고 자빠졌네',
#  '이재웅을구속수아하라',
#  '멍멍멍 \n카니발한대 가져와\n사줄게',
#  '나라가  어찌해서  타다갓은  회사한태 후둘리는지 이건  말두안되는  사업이지',
#  '타다 너무 양심없었지',
#  '불법 콜뛰기는 죄를 받아라',
#  '불법은사라져야죠!',
#  '누구닮아 양아치 짓거리만 하드만 잘됐다.노블리스오블리제!양아치가 돈많으면 이렇게 됩니다.거기다 대통령과도 유착됐죠?',
#  '이제웅 대표사기꾼',
#  '타다운전자법인택시일자리엄청나다',
#  '국난을 불감하는 국회 ! 개 ! 악 법의 독재 자 ! 문 재인! ! 속히 파면 하라!!!',
#  '합법좋아하시네',
#  '신천지와 타다는 사회를 좀 먹는 사이비다.',
#  '이게나라냐?부정도나라가정당화시켜주나~!',
#  '택시도 카니발 스타렉스\n차량  다변화가되야할것같네요',
#  '언론을장학한 정부 법도없는정부 여론몰이 선수 나라를홀난하게하는 정부',
#  '타다 기사  ?\n택시 영업  안되서 ㅡ 그냥 회사에 입고 되어있는 택시\n무지 마너요 ㅡ 택시 하면되지. 왜 타다야   .?ㅡ\n혁신 모빌리티 ㅡ 다같이\n죽자고 하는 짓거리 .',
#  '라이센서를 구입해서 정정당당하게 해주세요!!!!',
#  '타다는 나중에 딱지값 챙기려 한 사업이다..1500대면 대당 1억만 되도 1500억 이네..ㅎㅎ',
#  '입법하는사람이합법불법을구분할줄모르니양심은있나봐\n불출마한다고했으니',
#  '표결없이 통과하는게 전례가 없어야 하는거 아니예요?? 제가 이상한건가??',
#  'ㅋㅋㅋㅋㅋㅋㅋ원래  그랬대',
#  '예전 세녹스 = 휘발유가 필요없는 자동차 연료 이것도 정유사의 반발로 쭁.......',
#  '0:50',
#  '프사\n대한민국 \n우한폐럼 걸려 뒤졌습니다',
#  '공산독재네!!!',
#  '둘달밥맛',
#  '공수처법때 문희상 보고 국민들 맘이 어땟는지 이제 알겠냐?',
#  '편집을 웃기게했네',
#  '이야 북한이야?ㅋㅋㅋㅋ  그렇게 북한욕하면서 하는짓은 김정은이네 ㅋㅋㅋㅋㅋ 갓상규',
#  '겁나멋있어. ㅎㅎㅎ',
#  '여객자동차운수사업법, 운전을 생계로 하시는 특히 택시기사님들 운전이 도로상의 흉기로 변하고있습니다. 이점도 법적 강화가 필요할듯싶습니다. 택시기사님들 제발 부탁입니다. 모범운전을 보여주세요. 외국 지인이 한국와서 하는말이 한국의 교통문화 운전의 악습관은 택시로부터 다 보이고 그나라 교통문화가 보인데요.. 이말은 들은 자국민은 얼마나 창피할까요???.. 그렇다고 아니다라고 하기에는 너무 비현실적이고... 제발 부탁입니다. 타인의 생명과 안전에도 한번쯤 생각해주세요.',
#  '저게 미쳤나 진짜..',
#  '참 신기하다 연구해보아야 할 과제:  사람은 언제부터 꼴통이 되어가는가?',
#  '진짜 미친......저렇게 해도 미쳐버린 국민들이 뽑아준다...회의는 뭐하러해!!!!예전에 판사였을때 얼마나 억울한 자들이 감옥에 가고 고통을 받았을까???',
#  '권위적 그 자체',
#  '국회의원  올해 들어서  제일 잘한일',
#  '이런게 전통이라고? 썩었네',
#  '여상규 저 사람은 볼 때마다 소리치고있네 ㅋㅋ\n지멋대로할꺼면 법사위는 왜 열었어? 절차상?',
#  '부산만 하더라도 택시가 24000대인데\n무분별하게 타다같은 업체가 렌탈카니발 증차해봐라 30000대나 되어서\n온 도로에 택시랑 타다가 교통체증 유발한다.\n그래서 기여금 지출해서 운수사업법에 들어와 차량총량제에 동참하라는데\n돈 내기 싫다고 타가 서비스종료하겠다고\n국민들 대상으로 얄궃은 협박하는거임',
#  '타다가 카택처럼 운영하면 되는거 아님?\n카택도 한건데 타다는 왜? 못함?',
#  '최소한 국민의 안전을 위해서라도 운송영업 면허가 있어야지. 어느나라가 무면허로 운송사업을 허가해주나.',
#  '모범택시 카카오택시 블랙택시 타세요',
#  '저건금방통과되네 깬다',
#  '이용자 입장에서는 더 편리한 시스템으로 발전하기를 바라지만, 그 방식이 문제다. 대기업이 서민의 일자리를 빼앗아 가는 방식때문에 빈부격차가 더욱 발생하고 이 사회에 계층이 생기는 것이다. 지금도 사회 곳곳에 재벌 대기업들이 빨대를 꽂아 놓아 서민으로 흘러 들어가는 돈의 흐름을 방해하고 있다. 또 한가지 단점을 예로 들자면, 수도권이 아닌 지방에서 택시를 탔다고 가정하면 그 택시비용은 그 지역내에서 다시 돈이 돌아 소비가 이루어 진다. 하지만 타다를 이용하면 비용을 제외한 수익은 본사가 있는 수도권으로 돈이 들어 갈 것이다. 따라서 이런방식의 시스템에 의해 지방의  돈의 흐름이 점점 줄어들고 이에 따라 일자리도 감소하고 인구도 감소한다. 그리고 부동산 값도 감소한다. 반면 수도권은 돈의 흐름이 늘고 이에 따라 일자리도 늘고 인구도 증가한다. 따라서 부동산 값도 수도권에서만 증가한다. 이것이 한국의 지역 불균형의 모습이다. 시스템을 개선시킬때 자본주의 시장논리에만 맡겨놓으면 더 큰 부작용이 발생할 수 있기에 국가가 개입해서 공정한 방향으로 개선을 시켜야 한다.',
#  '신천지는댓가를치러야한다',
#  '타다는 영원히 불 타다. 축하한다. 정의는살아있다.',
#  '불법콜택시 타다 그이상 그이하도 아니다 면허ㆍ자격증 갖고해라 꽁짜로 쳐묵을려는 사기꾼ㆍ 카카오랑  충분히 한다',
#  '헐.. 택시보다 타다가 훨씬 좋은데 너무 아쉽네요. 택시기사님들 대부분 운전을 너무 험하게 해서 멀미 나고 싫어서 타다 좋아했는데..',
#  '타다금지법은 당연하다',
#  '발전이 없는 나라 너무 뻔한 기득권 싸움 다른 선진국을 따라 갈생각은 안하고 제자리에서 빙빙 돌기만 하네요',
#  '여객자동차 운수사업법에 안전사항 더 추가 안하나? 택시나 버스 신호무시, 속도위반, 차선위반 탑승할 때마다 운전사끼리 시비 붙는 일은 기본이고 대체 뭐하자는거지?',
#  '신천지와 타다는 이단이다!',
#  '타다가 위법이 아닌데 금지함...개택들이 분노해서~\n개택들 법규 2번 위반하면 택시면허나 취소해라',
#  '택시 영업도 힘든데   타다는 금지 되는게  마땅하다~ 잘하셨습니다',
#  '밥그릇 싸움에서 타다가 졌구만 외국은 새로운 플랫폼이 이미 자리를 잡아가고 있는데 우리나라는 기존 택시가 \n발목을 잡네....이래서야\n급변하는 세계정세에\n발을 맞추겠냐?',
#  "불법타다 나는 이제 안 타다''''",
#  '개택 해봤자 3명밖에 못 타고 타다는 15인까지 가능한데 효율면에선 타다가 나은것 같은데... 개택분들한테 묻고 싶다. 10 명 정도 단체 여행가는데 개택 이용해서 이동할지 타다이용해서 이동할지...',
#  '이때까지 전통이 그렇다고 하면서\xa0 계속\xa0 그렇게\xa0 갈것인가..??\xa0\xa0 이철희 의원만 흥분하고 다른 의원들은 다 가만히 있는데,,,,\xa0\xa0\xa0 잘못된 전통을 만든 역대 법사위 위언장 다 모셔다 놓고 청문회 한번 벌여서 제대로 잡아봐야 하지 않겠나...??',
#  'ㅋㅋㅋ',
#  'TADA !',
#  '이의 있습니다!\n가결되었습니다\n...?',
#  '이의있습니까???  탕탕탕  ㅋ  개그맨들 분발하셔야겠네요  개콘저리가라다',
#  '편집 우습게해놨음',
#  '타다금지하면 대기업처럼 자본력있는데서 면허비내고 기부금내고 싹슬이해버리면 택시기사없어지는건 마찬가지...결국 통신사 sk kt lg 나눠먹기처럼 될건데 지금은 대기업말고 는 타다같은 사업 손대지 말라는 이야기 아님???\n이거는 5g 자유주행 다 연계되서 대기업 독점시장으로 갈거니깐...자율주행으로 운전자 없이 서비스하면 여객법 피해가는거 아님???',
#  'The kingdom of the corrupt conservative party is the national assembly.  국회가 적폐 보수들의 왕국이 되었군요.',
#  '자기맘대로내 ㅋㅋㅋㅋ 자기가 운영권있다는식이네요. 그 운영권 국민 대리인 아닌가요? 공산당이네~',
#  '여상규 독재자',
#  '415   한 일전   꼭 투표 합시다♡♡♡',
#  '표결을 안했나. 뭐죠?',
#  '어차피 마음대로 할 것인데 회의는 왜하나 그냥 혼자 결정내리지.',
#  '면허ㆍ자격증 갖고하는 상가 앞에서  노점상 하겟다는 사기꾼일뿐   상생안도 무시  법규제 개무시   총량제도 개무시   카카오 마카롱 온다 등 각종 풀랫폼  잘만하고 잇다',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ씹개틀딱쉨ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '신천지와 타다는 사이비다.가결 찬성!!',
#  '독재네',
#  '여ㅅㄱ  20대 국회 끝나는 날 까지 진상이구나!!!!!!  🎃🎃🎃🎃🎃🎃🎃🎃🎃',
#  '와...  여상규의원...  내가 부끄럽네요. 이 영상을 보는 국민들이 여상규를 지켜봤다. 저 막무가내 발언 태도 다 봤다. 국민이 무섭지 않은지... 기본예의 좀 지켜라 소리지르지만 말고',
#  '앞쪽 부분을 볼 필요가 있을 것 같네요',
#  '타다는 현행법상 편법이라 금지법을 마련하고 위성정당은 현행법상 편법이지만 선거에서 이겨야 하니까 검토한다고..?',
#  '어이구야...',
#  '국회의원ㅡ자 여러분 어디가\n선거할때 표가 많죠? 민주주의의\n모든 법안은 그것을 기초로 만들어집니다 어떤거든 상관없이 그쪽으로 결정합시다',
#  '산으로 가는구나~~ 앞으로 혁신적인 아이디어로 누가 사업화 하겠냐? 그리고 타다도 면허를 사서라도 사업을 이어나가야지 장난하냐? 의구 길을 다 틀어막는구나~ 택시 나도 안탄다',
#  '이러면 법원은 뭐가되나',
#  '회사 사납금에 대해서 열불 올려봐라!\n무식한 택시 기사들아!!\n앞으로 택시 절대 안탈거고, 예상은 했지만, 택시에 대한 실망이 크다.\n제대로 배운거 없고, 먹고 살자니, 할 줄 아는게 운전 밖에 없어서 택시 운전하는 것들이!! 상생하자는데 그걸 이해 못해!!?',
#  '헐...ㅡㅡ;;;?!!!!\n진짜 어이없네',
#  '무식한 구시대에 머물러 있겠다-국회',
#  '택시기사 의무교육 시간도 넘어라 손님 태우고 방향지시등 안하는 쉐기들',
#  '해외엔 우버택시 한창인디...왜 우리나라만??정치판이 발전을 막는군...자한당만 없어도..가능?',
#  '택레기들 표가 좋긴 좋네...  국개들...',
#  '민주당 대단하다 ㅋㅋ \n이래놓고 경제 살리겠다고??ㅋㅋㅋ',
#  '1만명 실업자되네',
#  '비겁한 정부.표 앞에 무릎꿇었다. 전 정부와 다르다 할수 있나? 부끄러운줄 알아야지.다 똑 같구나.',
#  '금지찬성!',
#  '다행이다! 한국의 택시는 1억이 넘는 권리금을 안고 시작하는데, 이걸 미국의 택시와 비교하면 안돼지. \n이게 미국의 우버는 되고, 한국의 타다가 안되는 이유. \n한국 택시 기사님들 응원합니다!',
#  '불법 콜택시 타다  사기꾼 이재웅  동등한 경쟁해야지  꽁짜로 쳐묵을려니까 문제지 면허ㆍ자격증 갖고하면 될껄',
#  '와이티엔은 타다편향 방송  안하고 공정하게 양측 울화통 터지지 않게 겸손한 방송 엄지척..연합뉴스는 타다 옹호  많이 해서 와이티엔  시청할꺼임.',
#  '난택시가 싢다  왜냐하면 좋은택시 기사도있었지만   난폭운전택시기사 끼어들기  u턴차선에서 유턴하는데 욕하는택시기사  초등학교때 아버지가 택시기사하테 5천원지워주면서 학교까지 태워달라고했는데 분명2천원나와서 택시기사하테말하니 5천원맞다고 비양심적택시 기사 난그래서 택시를증오함',
#  '중국애들 몰려드네',
#  '택시 표심 겁나서 ㅎㅎㅎ',
#  '국민의 다수가 원한다고 불법을 지양할순없는겁니다. 타다는 애당초 무허가콜택시사업이었습니다.\n무허가 업자가 동종합법사업자의 생존권을 위협하는 만행이었지요.\n편의점을 예를들어볼까요? 가뜩이나 한집건너 두개씩있는 포화상태의 동네편의점 앞에 무허가포장마차식 편의점들이 우후죽순 생겨나서 더욱더 질좋은 물건을 팔아재낀다면 이게 4차산업혁신인가요? 정식편의점들이 살아남을까요? 그럼에도 불구하고 국민다수가 불법포장마차편의점을 선호한다면 상생관계가 되도록 길을 열어줘야하는건가요?',
#  '면허증따고 자격증따고 해라\n\n나? 면허없이 면허있는 파일럿보다 비행기 잘모는데 내비행기 탈래?',
#  '저 이해 안 되는 데 요약 좀 해주실 분?',
#  '내 기억속의 택시는 기본요금 나왔다고 카드로 결제한다고 얼굴 찌푸렸던 택시, 물웅덩이 앞에 내려줘서 내리자마자 신발 젖었던 기억밖에 없네요',
#  '영 거꾸로 돌아가는듯한...',
#  '저는  택시와 관련  없는 사람입니다    다만   타다라는  업태 형때가 운수업  이다보니   택시업  관광버스  사업자와  겹처  있는  형태  입니다      당연히  택시와 버스사업자 들의   피해가  발생 할수  있다  볼수  있습니다         운수업 등록하셔서 정식으로 영업하시는 것이 옳은  것이라 생각 합니다',
#  '참.. 우린 왜 역으로 가냐...',
#  '선거의식   겁나   하네',
#  '콜뛰기 타다와 신천지는 박멸이 답이다.',
#  '택시 서비스 개선 일도 없는데 경쟁이라도 붙게해서 서비스 개선이라도 하게 해야지 이건 뭐 요금은 요금대로 올려주고 거부는 그대로고 옛날엔 섯다 목적지듣고 쌩간다면 지금은 서다가 그냥 줄행랑 치는데 더 나빠진거 아니냐?? 이런 고충을 정치인나리께서 알리가 없지',
#  '이제 뭐타고 다니나...ㅡㅡ 택시 탈 생각은 죽어도 없는데... 아오',
#  '타다서비스는 엄연히 법의 허점을 이용한 불법적인 사업인데 이걸 없애는걸 이상하게 생각하는분들이 전 이해가 안갑니다.\n물론 진상택시기사, 난폭운전, 승차거부 같은 택시들도 많은 문제가 있는것은 사실이지만 그렇다고 불법인 타다를 옹호하는건 아니라고 생각합니다.\n정말 택시가 개선되려면 불법이 아닌, 택시들과 같은 출발선에서부터 서로 경쟁을 시켜야지 택시쪽에서도 강하게 주장할것도 없고, 서로서로 좋은 경쟁효과가 생길 수 있는데, 무조건 적으로 타다를 옹호하는건 아니라고 봅니다',
#  '부산만 하더라도 택시가 24000대인데\n무분별하게 타다같은 업체가 렌탈카니발 증차해봐라 30000대나 되어서\n온 도로에 택시랑 타다가 교통체증 유발한다.\n그래서 기여금 지출해서 운수사업법에 들어와 차량총량제에 동참하라는데\n돈 내기 싫다고 타가 서비스종료하겠다고\n국민들 대상으로 얄궃은 협박하는거임',
#  '우리나란 망할꺼야 이런식이면',
#  '국회의원 꼬라지 봐서는 택시들 승차거부 과속 난폭운전은 영원히 사라지지 않겠내 ㅋㅋㅋ\n역시 이나라는 선거전에 표걸고 떼법 밀어붙이는게 최고여 ㅋㅋㅋ',
#  '사기꾼 이재웅  투자 이외는 돈이  없어 1년6개월 못버티고 한달도 안되서  운행정지 하는놈',
#  '4등!!!',
#  '얼론이타다를왜자세히다루는지이해가안됨',
#  '4차산업  공유경제     뭘  공유했는지  아는사람?  이재웅  서비스  접는다며  빨리  실천하길',
#  '당연하다   지금도  택시가 맗은데 교통 만혼잡하다',
#  '택시업계에서 성실히 법을 준수하며 생계를 유지해온 택시업계 종사자를 보호하고 타다를 즉각 영업정지 시켜라 ㅡ',
#  '타다가개색키들의집단이지뭥ㅑ',
#  '대통령이 니 형이냐! ! !',
#  '성폭행은   죄다.\n택시기사든데~~',
#  '부산만 하더라도 택시가 24000대인데\n무분별하게 타다같은 업체가 렌탈카니발 증차해봐라 30000대나 되어서\n온 도로에 택시랑 타다가 교통체증 유발한다.\n그래서 기여금 지출해서 운수사업법에 들어와 차량총량제에 동참하라는데\n돈 내기 싫다고 타가 서비스종료하겠다고\n국민들 대상으로 얄궃은 협박하는거임',
#  '뭔개소리냐. 법으로. 무죄인데. 개택시들이. 얼마나. 사고가많은지모르지',
#  "It is very hard to find a solution for this issue between the existed taxi union and the digitalized taxi system, 'Tada'. 기존 택시 조합과 디지털 택시 시스템인 '타다' 사이에서 이 문제에 대한 해결책을 찾기는 매우 어렵습니다.",
#  '빙고~정답 말씀●김현미 국토부장관 말씀이 맞는것 같네요~법치국가.법 틀속에서 뭐든 해야된다고 봅니다\n■■진보.좌파 논객~동양대 진중권교수님\n●●이완배 기자님.경제의 속살~방송을 보면 왜 불법인지를\n■타다가.불법을 행하고 있는것을 속시원하게~아주 이해하기 쉽게 쏙쏙 풀어 펼쳐서 설명하시니 누구나 이해가 싶죠~한번들 보셔요\n■■진보.좌파~논객 말씀을 들어들 보셔요',
#  'ㅉㅉ   멋도   모르는애를   저자리에   앉혀놨더니 구시대는    이래서   안대',
#  '재수없다 ㅉ',
#  '타다 청와대 입장 밝혀!타다금지법은 대통령거부 사항 아니다. 라고 밝혔다.',
#  'ㅠㅠ',
#  'ㅋㅋㅋ웃기시네',
#  '말장난 하지 마!',
#  '타다는 사이비다.',
#  '우버가 안되는 갈라파고스 제도 ㅋ',
#  '김현미 유은혜 박영선 이 세사람의 공통점은? 1.낙하산 2.맡고 있는 직책에서의 무 경력',
#  '타타 금지하려면.. 카카오 택시도 금지해 보던가....',
#  '택시 이제부터 자성하고 택시 제도권 안으로 들어온 플랫폼과 같이 성장합시다!타다는 양아치 기업 이였습니다.택시에 모순점을 보고 파고 들어온 사기꾼이지 4차산업도 아닙니다.콜띠기 업체에 불과합니다.',
#  '그냥 택시를 위한법이지 무슨..',
#  '말 같은소리를 해라 !! \n그라먼 ??  택시만 상생하냐 ??  타다도 상생해야제 ???\n정부가 할 역할은 양쪽 모두를 살릴수 있는 중재와 방법을 연구하고 조정하는 일인데 무조건 한쪽편 입장만 편들고 상대방은 막아버리면 앞으로 새로운 비지니스 아이템과 발전은 없을것이다 !!\n그리고,  그따위식으로 머리숫자..  표만 생각하는 정책은 씨벌 나도 하것다 !!\n말은 잘갔다 붙혀요 !!\n상생 ??  상생은 너거가 맨날 떠드는 더불어 사는거다 !!\n근데 한쪽 편들고 한쪽은 죽이는 거는  반생이지 ???',
#  '정부가 택시 독점을 독려하네 미친거아닌가;',
#  '택시사업이 혁신산업인가ㅡ?\n돈에 눈먼 재웅아ㅡ거짓의 가면을벗길바란다ㅡ',
#  '나라가 거꾸로 흘러가네ㅋㅋㅋ시대의 역행이다',
#  '여상규 진짜 ㄹㅈㄷ',
#  '타다는 처음부터 불법 자가용 흰 번호판으로 승객 태우고 영업을하면 당연히 불법이지',
#  '이름이뭔테요',
#  '이재~~~~우웅~~~~가나!!',
#  '우리나라 틀딱때문에죄다금지여기댓가관이다ㅋ',
#  "'타다 보니까~  닮은꼴~ 더불어정부 보는거 같네요",
#  '틀딱들 토나오는 댓글 많네ㅎㅎ',
#  '이정부는 시장논리대로 되는게 하나도없다...간섭해서 잘된거하나없는데 나라살림은 엉망진창 지들멋대로 말아먹으면서\n어쩌다 이나라가 이지경까지...',
#  '정부가 간섭해서 죄대로 되는가 없다. 결국 외국의 플랫폼이 들어와서 장악하것지',
#  '법의테두리 안에서 장사해라~혁신은 이런데 쓰는게 아닙니다~개나소나 타다하면 법의질서가 필요할까요',
#  '타다는 면허도없이  서민들 일자리 뺏는 악덕 기업이다',
#  '무슨혁신 개풀뜨더 소리하고 있네요',
#  '불법영업  당연한데 왜  논쟁벌리고 자빠졌나',
#  '정말무슨 빽으로 정부와정부와국회까지 죽었느니 해가며 저러는지 이건 국회모욕이다',
#  '불법콜택시 타다  면허ㆍ자격증 갖고하면 될껄 꽁짜로 쳐묵을려니까 문제지   총량제 법을얍보고 우숩게 아는 노점상에 불과하다',
#  '기존의 택시영업의 형태를, 렌터카라는 방식이 운송사업법의 맹점을 이용해 조금 변용해서 영업하려는 것을, 무슨 혁신이라 하는지. 도대체 이 정부의 혁신의 기준은 먼지 애매하다. 혁신은 그야말로 창조적인 아이템에서부터 시작되는건데 말이지. 결국 정부가 바람 윽스루 집어넣고, 수많은 사람 김빠지게 만든 꼬라지.',
#  '좋은건 알겠는데 맨입으로 숟가락 얹으려니 문제지\n제발 스타트 업이니 4차 플랫폼이니 무늬만 그럴싸한거 하지말고\n알맹이를 제대로 하자 가만보면 기존 업종들 껍데기 바꿔 지들 배만 불리니 원\n배달앱부터 봐라 옛날 중국집 슈퍼는 배달 안했냐?',
#  '대통령이 니 형이냐 ! ! !',
#  '기어이',
#  '타다차량이 1500대인데 기사가 12000 명이냐 한대당 10명식운전하냐    입만열면 구라야',
#  '훠훠훠~그럴시간없어!중국댓글알바 알바비주기도 바뻐!훠훠훠~~',
#  '문재인 평양방문때 \n왜 이재웅을 동행했을까?\n\n 이재웅 뒤에 문재인의 엄청난 백그란운드가 숨어있지 않을까?\n대통령 거부권행사하면\n이번 총선에서 택시가족 100만표 아작날걸!',
#  'It is all about how to cut the limited apple pie in taxi business for all. 그것은 모두를 위해 택시업계의 제한된 사과 파이를 자르는 방법에 관한 것입니다.',
#  '차라리 영업용번호판 매입비를 달라고하지 그게 덜 구차해보이는데',
#  '재이니형한테가서징징짜거라',
#  '문재인과 디기 친한갑네.',
#  '응 통과됨 타타 ㅉㅉ',
#  '일반택시기사 운전도 못하는 것들이 말 많아서 조용히하고 빨리가자고 하면 그때부터 난폭운전 시작함99.99%',
#  '기존택시도 공짜로 번호판줫엇는데\n반납안하고 권리금을붙엿으니\n공짜로 정부에서 번호판 새발급을\n해야할것같네요',
#  '타다의 기사들이 정직원의 고용일까?\n\n불법파견 계약직기사임!',
#  '신천지와 타다는 사이비다.',
#  '승차거부 택시양아치들',
#  '서비스의 서 자도 모르는 택시에 손들어 준 걸 보니 문재앙과 택시(기사) 사이에 끈적한 연이 있는겁다',
#  '1인 택시회가 가능해야 혁신이다\n내 노후 국가가 책임질것 아니면\n허용해라 더 일하겠다는데\n왜 막느냐 스벌',
#  '역시 재벌언론 답네',
#  '2020년의 적기조례',
#  '제발 국회통과된안을가지고  이상한쪽으로매도하는뉴스는하지마세요 정말한심한뉴스거리네요',
#  '한민용 아나운서님.... 최근 2번이상 단어를 씹는듯해요. 오늘의 시작은 “한일간...”이부분 씹으시고ㅠㅠㅠ.',
#  '근데 표가 움직이는걸 어떻하냐...\n\n종교인표 택시표 이걸 어케막냐고\nㅋㅋㅋ 당사자들이 상관없이 투표를\n해야되는데.. 답없지\n\n투표율이 개높아지면 모를까...',
#  '한심하지',
#  'Jtbc불법을옹호하네',
#  '공유플렛폼 타다를 통해서 뭔가 타다가 가진 문제점이나 다른 아이템에서 이런 저런 문제점 세밀하고 좋은 방향성을 제시하면서 다양하게 이루어지면 좋겠다 했는데. 솔직히 택시는 택시들이 직접 나서서 지들 사납금 철폐 전국대규모 시위 안하는 이상 밀어주면서 인정해주기 싫은 상태',
#  '부산만 하더라도 택시가 24000대인데\n무분별하게 타다같은 업체가 렌탈카니발 증차해봐라 30000대나 되어서\n온 도로에 택시랑 타다가 교통체증 유발한다.\n그래서 기여금 지출해서 운수사업법에 들어와 차량총량제에 동참하라는데\n돈 내기 싫다고 타가 서비스종료하겠다고\n국민들 대상으로 얄궃은 협박하는거임',
#  '우리나라 국회, 정치인들이 하는게 그럼 그렇치. . . 얼빵이들',
#  '난 이제  중앙방송안보고   경멸한다   손석희  석고대죄 하라',
#  '타다 입장에선 택시가 기득권이지  타다 이재용사장이 우리나라를 제대로 이해를 못했구만 안타깝네.',
#  '그니까 타다금지법은 정부여당 욕할일이아니네....야당추진으로 통과네..그럼 타다 애용자들은 4.15때 여당에 한표~? !  아리송',
#  '택시 없애고 타다 가자',
#  '애초에 기존에 택시 좀 줄여야지 시대가 시대인걸',
#  '야... 이건 진짜 아니다... 기득권 택시의 표를 받고자 정치꾼들이 기득권을 편든다?\n새로 시작하는 스타트 업체 타다를 조지네? 이래서야 스타트업이 살아남겠냐?\n한국의 금융업체가 썩어버리고 발전이 안되는 이유이기도 하다.',
#  '정작 택시기사들 회사 사납금에 대해선 찍소리도 못함.',
#  '25만 개택시 기사만 유권자냐?',
#  '면허사서 합법적으로 할생각을해야지!!!\n이게4차산업이러면 5차산업은 \n판사,검사,변호사들도 말잘하고 법공부한사람이면 앱으로 호출해서 채용해!!\n의사들도 수의사들 매스만 사용할줄 알면  앱으로 호출해서 고용하면 아주 멋진5차산업이겠다',
#  '택시는규제가많고 타다는 규제가없으니 당연히비교가될수밖에\n규제풀고 동등한조건으로 한다면 이해하겠는데',
#  '제2의 바다이야기!',
#  '저는 의사면허사서 병원하나 차려볼려고요',
#  '말장난 너무 심하게 한다 교수라는 분이 무엇이  공유경제야?',
#  '택시가 서비스만 좋았어도.. 맨날 승차거부에 서비스도 별로. 경쟁 대상이 없으니까 경쟁 업체가 생기는 것은 당연',
#  '저도 저거랑 똑같은거 준비중입니다.',
#  '우리도 법인 택시 때려치고 렌터카빌여서 영업합시다 합법이라니  하면되겠네 생각없는 판사새기 돈을 얼마나 처먹은거야',
#  '택시규제다풀어줘라 카니발풀옵숀사서 명함뿌려전화로콜 영업하면 돈더벌거갔은데 이러면타다나나나 이건불법이라고할려나 개법ㆍ양식도 없는사람 나는지금의논평인 나오면 바로채럴돌림 학교가학생들이 아가ㅃ다',
#  'ㄹㅇ 다행이다',
#  '1.주문형 초단기 렌터카 : 택시도 예약주문으로 잠시 빌려타는개념임.\n2.승합차 임대 : 처벌하는것은 아니지만 기존 여객운수 사업법을 보호하자는 취지.\n3.고의성 없어 : 정부와 협의를 했다고는 하나, 국토부나 정부로 부터 명확한 답변 없었고 협의체를 통해 해결책을 찾으라 했음에도 타다측이 반대함.\n4.택시보다 비싼요금 : 시장의 선택을 법원에서 왜 판단을 함? 법정은 법리적 해석을 하는곳임.\n\n\n이것을 명확하다고 표현하는 에스더도 좀 한심한것 같고, 타다 무죄가 되니 아주 신이났음. 그렇다면 앞으로 언론도 가짜뉴스라며 공중파가 아닌 매체에서 보도하는 행위에 대하여 법적책임을 묻네 마네 하는 보도는 않냈으면 함. 보도와 언론의 혁신도 이미 턱끝까지 와있음. 잘난 기자 나부랭이들 보다 전문적인 네티즌의 글들이 점점 신빙성이 있어짐. 기레기라는 말이 괜히 나온것이 아님.',
#  '기자와 논평인들은 과거 기타항쟁에서보여주던 정신으로 돌아가라 정치하지말고 ㆍ돈따라가지말고 영화같은데서보던 숭고한기자들은 다죽고 눈에보이는것만이 다가아니란것 그진실을 파혜치고 진실을 알리는게기자다 내가집에가는데 택시가안태워줘 기분나빠 이게아니란것',
#  '바다에나가 면허와 자격없는 배로 마음대로 물고기 잡으면 될까요?\n최소한의 상식도없어 보입니다.',
#  'ㅎㅎ 완전 골때리네.  면허가 없는데, 운송업을 한다?  그럼 나도 카니발 수십대 사서  타다2만들어서 하면 되는건가요?   완전 쇼킹한다.',
#  '판사는  돌대가리냐     렌터카로  앱 콜을 만들어  손님 1~명 그이상 태워 지역 제한없이  돌아다니는 특혜를   타다 이재웅만 위한  영업을   정상으로 보는  판사 새끼는  이재웅과 뒷거래가 있는것 아니냐  렌터카법은 차를 대여 하는 목적에 기반하는  법으로 만들어진것이고   기존의 택시영업은  여객운송 사업법을  기반으로 손님을  태우고  이동시키는  유상운송  영업을  해온것이다  타다는  택시 영업에  피해를 주는  \n 영업을 하고 있는 것이다   기업은 불법렌터카 영업을  해도  된다는것이냐  이재웅이  렌터카 영업을  11인승  이상 기사를  딸려 보낸다는 법에 적용해서  타다영업을  한다고 했는데    11인 이상  인원이 렌터카를  대여  했을때  기사를 딸려보내야  뜻이   맞는 것이지 한두명까지 이동시키고 지역 제한없이 돌아다니는  재벌의 특혜를  혁신이라고 하는  판사 개새끼는  정부의 제한된  제도권안에 택시사업을  하고있는  피해자들을 생각해 봤냐  타지역 이동금지가 되어있고 5인승이란 제한도 있는것이다 소비자의 선택만 위한  판결을  해야  하는것이 아니라  평등하게   사회 일원 모두에게  적합한  법이어야  한다  돈많은  재벌에게 특혜를  줘야 하는것이 판사들의  권력이냐   개인의 재산  전체가  매달려 있는  택시 산업을  생각  한다면  렌터카는  차를 대여 하되  택시사업을 짓밟지 않는 방법을  택해야  할것이다  이재웅이  렌터카법   11인승  허가를 받을때  갑자기  들고온 문제다보니  국토부도 법해석에  선을  분명하게 긋지 못했던 것이다  국토부 담당자들도  법해석을  잘못하고 있었던것을   난알고 있다   이재웅이  갑자기  들고나와서  합법인것처럼  몰아붙이니  국토부도 뒤늦게  판단이 잘못됐던 것을  그들의 실수를  뒤늦게  깨닿고  판결을  보겠다고 했었다  그러나  판사새끼의   재벌 밀어주는  평등하지 못한   판결을 하며   전재산  들여 개인택시   사서   뼈빠지게 일해가며  재벌 상대로   경쟁을 하라는거냐  택시는 정부정책에  매어있고 타다는  거대자금들여 지역 제한없이   한명도 두명도  태워 이동시키는 유리한  혜택을 왜 타다만 누려야 하는거냐   판사놈 사퇴시켜야 한다   혁신은  개인의  이익이 더앞선것을  혁신 이라고 해야 하는것은  아닐것이다  이재웅 재벌을위한  타다 무죄 판결을한    판사새끼  뇌도 정상이 아닌것으로 생각된다   기존의 택시사업은  개인 사업이 아니라 정부 정책대로 끌려다니며  제한된 영업을  해온것이다  국토부도 타다가 정상영업을  하도록  하려면  여객운송법적용   허가를 받고   택시 사업에  동등한 영업을  하도록  카카오처럼  타다도  같은 규칙 아래서 영업을  하도록  해야 할것이다   국토부는 타다 금지법을  통과 시켜야 한다  여객운송법을  잘 알고 있는  국토부는  타다가 불법 영업을  하고 있는것을   아니라고 말못할것이다   국토부가   올바른  일처리를  못한것 때문에  불법을  합법이라  밀어붙여  수백억의 돈을 벌어들인  타다는   불법영업이다   택시와 동등한  허가를 받아  동등한 선에서 영업을  해야  할것이다',
#  '정말 다행입니다.',
#  '타다더비싼데도타자나  택시가 좋으면택시타게지',
#  '택시 눈치보지 말고 국민들 생각해야 한다. 언제까지 국민들이 택시의 노예가 되어야 할까. 법원의 판단 존중한다.',
#  '다행이다. 공용서비스사업 확대해야한다. 에어비앤비도 글코 우버도 글코 한국만 불법이다. 지들 밥그릇뺏길까봐 새로운 사업은 막고보는 기득권은 땡깡만 부리지말고 새로운 변화에 적응좀 해라쫌',
#  '최악. 전국 택시 수 절반으로줄여라',
#  '타다 금지법이라니!!공산국가?? 또 정부 규제??',
#  '잘하는 짓이다ㅋㅋ 자유경쟁보다는 통제가능한 사회주의 시스템이 좋다는건가',
#  '정부는 왜 시대에 역행하나요?',
#  '헐 일자리 없애다니',
#  '경제폭망 외교폭망 의료보건폭망 통일안보 폭망 어느거하나 제대로하는게 없는 무능저능뭉재앙정권 ㅋㅋ 미국은 우버리프트기업이 창출하는 일자리와 부가가치가 천문학적인데 한국은 아직시작도 못하는 이유 시진봉만도 못한 지도력덕분 ㅋㅋㅋ 문좌빨기업 네이버는 기살려 반문기업 카카오는 기죽어 ㅋㅋㅋㅋ ㅎ',
#  '잡초와 바이러스는 빨리 박멸하며여야 한다',
#  '강남언니들 집합했네',
#  '택시 평점제 도입 국민청원.. 아래 링크',
#  '웃기네',
#  '역겹다 진짜',
#  '여상규 저 미친노인네 택시기사들한테 표하나라도 더 얻을려고 발악을하는구만',
#  '얼논은중요한이야기는빼먹고이야기하는데.예외조향은11인승에서15승..장애인.외국인.가족들중큰일에.2종먼허나.부덕이운전활수업는경우에만허용했는데...........이.이약기는빼먹고얼논은모두사기을치고있음니다.......타다는.말할가치도없다.💣💥💣💥',
#  '웃기는 소리하네 아니 할게없어서 택시를  그게 스타트업 이라네 사회적 파동이 더크지',
#  '이재웅.사기꾼에.말로를.보게될겁니다.정직하게삽시다',
#  '김용태 이사람 블로그에 타다관련 입장문 아주 가관이네 어느나라 국회의원인지 의심스럽네\n\n2020.03.05. 20:18:23\n\n답글0',
#  '언론 기레기들아 불법을\n합법으로 중계해주는 ㅉㅉ',
#  '타다는 불법택시임 택시회사를  사서하면 됩니다 미래하고는 상간없음',
#  '당신이 택시 시장을 날로 먹을려고 했던게 나쁜 선례이다.',
#  '정부 미래가 없다',
#  '타다는 대한민국에서 떠나세요.택시가 넘치는 나라입니다.',
#  '면허사서 합법적으로 할생각을해야지!!!\n이게4차산업이러면 5차산업은 \n판사,검사,변호사들도 말잘하고 법공부한사람이면 앱으로 호출해서 채용해!!\n의사들도 수의사들 매스만 사용할줄 알면  앱으로 호출해서 고용하면 아주 멋진5차산업이겠다',
#  '불법이지',
#  '좀 공정하게삽시다',
#  '말만 교묘히바꿨지  또다른 택시영업',
#  '발전이 없네 그냥 막아버리네',
#  '결국 모빌리티하려면 택시사업을 하라는거네ㅋㅋㄹ 택시회사를 세우란건가? 사납금으로 운영하는?\n그 사납금 때문에 택시가 승차거부하는거라며?\n택시는 30년 전이나 지금이나 차만 바뀌고 발전없이 똑같은데 향후 30년도 똑같게 하라는 법이네.\n2050년에도 승차거부 당하겠네ㅋㅋ',
#  '택시금지법은 안해주나?',
#  '그 표를 얻어내려고 나라를 후퇴하게 하는구나',
#  '결국은 택시들 지밥그릇 챙기는거 아냐\n길거리에 널린게 택시인데 밤만되면 안잡힌다 또 주말에 유흥가랑 변화가는 더더욱 전에는\n강남에서 반포까지 걸어가서 택시 겨우타고왔다',
#  '스타트업을 하고 있는 대표로써, 우리나라에서의 혁신 창업은 불가능하다. 소외계층인 장애인분들을 위한 맞춤형 서비스를 제공하며 나라에서 요구하는대로 4대보험을 보장하고 사법부에서도 무죄로 판정받았지만, 참 한심한 정부와 국회입니다. 멀지 않게 느껴져 두렵네요.',
#  '에휴... 아무리 봐도 한국에서 스타트업이나 모빌리티 사업은 무리인가보다... 아마 몇년 후에 해외 모빌리티 플랫폼이 진출하기 시작하고 나서야 법안 완화되고, 해외 기업에 한번에 먹혀버리겠지.... 대한민국이 뭐 이렇지.',
#  "'증기기관의 발명지,제조업의 시작 영국'은 '강성마차노조의 반발'로 인해 영국내에서 자동차를 타는것을 금지시켰다.\n그로인해 영국의 자동차 기술자들은 미국과 독일로 넘어갔으며 영국의 자동차 기술력을 수십년 퇴보 시켰다.\n\n\n우리나라의 모빌리티 산업은 '강성택시노조'로 인해 수십년 퇴보할 것이다.",
#  '이 정부는 진정한 진보정당이 아닌거 같다.. 개혁과 발전을 저해하는 짝퉁 이단 정부인 것같다...',
#  "법원에서 '무죄판결을 받은 타다'. 정부는 '위법으로 만들기 위해 개정안을 바꾼다'. \n\n소비자의 선택권보다 달콤한 택시노조의 25만표",
#  '타다는불법!타다아웃!!',
#  '무슨혁신?',
#  '역시 판사보다 국회의원이 한수위네\n무죄 판결한 판사 쪽팔리지 안나',
#  '그니까 지금 흔히들 부르는 진보주의적 정부 및 여당은 자유시장의 흐름대로 타다를 인정했는데 정작 자유주의를 지켜야할 보수들이 자유시장의 흐름을 막고 국가의 시장개입을 강조했다는거? 이야 흐름참 이상하게 간다',
#  '정부 문제가 아니지. 국회가 문제지.',
#  '문재인 빽 믿고 설치더니 ㅋㅋㅋ 고소미',
#  '이인영과 마포5인은\n신을사오적 척결하자!!!!!\n저인간들은\n눈만뜨면쑈쑈쑈 입만열면거짓말\n국민들은 무능한 문정권과 무능하고 선동질 막말만하는 더블당에 등돌렸다!!!!!!!! \n심판받을것이다~~~~~',
#  '여객운수사업법 개정안  쓰댕아\n타다 금지법이 아니라',
#  '그러니 너희들을 삼류\n라는 것이다 .',
#  '추경통과 안해준다고? 진심으로? 미쳤구나..',
#  '타다금지법이 아니라 여객자동차운수사업법 개정안입니다\n그리고 타다가 주장하는 4차 혁신산업은 이미 카카오에서 정식영업용 번호판 구입해서 영업중입니다',
#  '수신료를 내지말자  국민의방송? 개뿔 편파방송 개방송',
#  'Kbs 수신료 안내는 방법없음? 요즘 kbs지역방송보면 완전 선거방송임. 찌라시수준의 기사로 여당빨아재끼느라 정신이 없음. 이런것들이 세금으로 방송 만든다는게 믿기지가 않음',
#  '개 젖같이 피빨아 먹는 운영방식이\n4차혁신?!!  뭐라고~?!\n양아치 자슥~!!',
#  '택시도 정신차리고  잘해야 된다',
#  '희대의 사기꾼...',
#  '택시도 문제지만 타다는 불법이라고 생각된다',
#  '저차들  다  어쩌냐',
#  '국회 국민 모두 죽였다\n그럼  이제  대한민국\n유령이니',
#  '혁신 좋이하네  법을어기는놈',
#  '니네말안들어주면 정부 욕하냐 ᆢ법사위장 이누고 ᆢ너든 맘보가 틀려 처무다ᆢ마ㆍ고마해라 ᆢ사회적혼란만  부추기고 사과하는게 맞잔냐ᆢ양아치도 아니구ᆢ참~',
#  '앞으로는 자율주행차들이 택시를 대체\n자동차는 개인이 아닌 대기업들만 구매할텐데\n인건비 들어가는 사향산업을 왜 포기하지 못하냐',
#  '카니발 중고 싸게나오길 기다리는1인',
#  '이의있습니다 \n응 그건 니생각  난 내방식대로한당',
#  '렌트카허가로택시처럼하는건불법입니다택시회사인수하여태두리안에서하면됄것을 왜저토록사회를어지럽히는지이해불가다',
#  '제도권으로들어와서 혁신을하던4차산업을하라고\n앱으로콜튀기를사탕발림으로 포장하지말고',
#  '타다는 손안대고 택시영업하고픈게  너의 한계다  운수사업법이  엄연히 있는데! 혁신은 무슨 개풀!',
#  '타다 아웃 잘햇다',
#  '타다 기사들 택시회사 취업하세요. 환영.',
#  '타다 ㅡ 당연히 불법이지 .\n합법 판결내린  판사 이해불가 ㆍ',
#  '타다가 합법이면 수술실 간호사가 수술하면 되나요 주객전도. 택시는 규재가 심하고 타다는 제멋대로  이게 정의로운 세상인가.',
#  '아...그러니까 못하게 하는게 아니라\n제도권 안으로 들어와서 해라가 맞는 거군요?\n오히려 정당하게 사업할수 있도록 도와준거네',
#  '면허ㆍ자격증 갖고하면 될껄 꽁짜로 쳐묵을려는사기꾼  타다 이재웅',
#  '잘됐다.\n렌트임대사업이나하지',
#  '업체와 드라이버들을 전혀 생각하지 않는 타다 \n운행 중단한다고 서서히 배차도 줄이는 타다 \n때려쳐  택시가 타다를 물리치세요',
#  '이렇게 한국의 미래를 바꿀 기업 하나를 죽이는구나. \n돈없는 거지새끼는 사업하지 말라는 좋은 교훈과 함께..\n\n먼 미래도 아니고  5~6년 뒤에 우버나 디디추싱이 넘어와 상용화되면서\n왜 우리에겐 우버같은 혁신적인 기업이 없냐고 하겠지. \n뒤늦게 정치인들이 한국형 우버 육성 사업이라고 대문짝만하게 공약 내걸면서 정치질 할꺼고. \n그걸 핑계로 인맥 닿아있는 대학이나 사람들이 2+1, 3+2 프로젝트 같은 장난질로 끼리끼리 돈잔치 할거고.\n그렇게 고등학생들이 수행평가로 만든 듯한, 애들 장난같은 결과물 만들어놓고 잊혀지겠지.\n래퍼토리가 너무 뻔해서 지겹다.',
#  '공짜좋아하면똥구멍에뿔난다아거들아',
#  '정식.허가내서.영업 해야지. 종합보험도 택시와 동일하게. . 염치없는인긴.',
#  '억지부리는얄미운 오리새기같아  안된다는대 에미에게 죽는다고 협박하고 무래기대려와 시위하고  유서쓰고 집나가고뭐야그게',
#  '법안을 통과에 찬성한 국회의원 명단을 올리세요. 안뽑으면 되지.',
#  '여객운수사업법 개정안 이지\n타다 금지법이 아니고',
#  '선거철되니 택시노조 무섭지.',
#  '마스크 대란대란입니다. 문재인 정부가 마스크 관련해서는 처음부터 잘못 조치한 것은 맞습니다. 그럼 미통당의 대안은 무엇입니까? 비판만 하지 말고 대안을 내놓으시기 바랍니다.',
#  '타다금지법이 통과된것에 매우 유감을 표한다.그렇게 택시노조가 무서운 존재인것인가?물론 택시가 타다로 인해 얻는 매출의 피해가 있더라도 택시에 대체자로 타다를 이용하던 시민들에겐 매우 슬픈 일이 아닐수 없고,택시노조로 또 이렇게 참신한 벤처기업가를 탄압하는것에 매우 분노를 느낀다.',
#  '승객한테 돈받고 영업하면 당연히 불법이지!',
#  '미래통합당 kt한테 뭐 받아먹었냐\n김성태도 그렇고 도대체 kt랑 뭔 관계\n국회 본회의 파행까지 할만큼',
#  '박용진 ㆍ 추혜선  예리한 지적  법안 부결시킨 민주당 믿음직스럽습니다.',
#  '👎👎👎文👎👎👎',
#  '법치국가에서법안으로들어오라는말인데~~~왜독불장군인가~~~불법탈법으로~~~~',
#  '배민처럼 키워서...비싸게 팔고 먹튀 해야하는디...그걸 몬해서...삐졌군....',
#  '그걸 단호히 지식인들이 청소해주면좋을텐데 무슨 욕망으로 이런 문제를 계속주제로 영양가없는 토론을 열고 좌담회를 열고 입담을 과시하고 궤변도 늘어놓고 참 세상 복잡하게 삽니다 ㅡ목구멍이 포도청이라 틀린 제목도 토론감이되는 모양이지요ㅡ수많은 토론감이 있는데?',
#  '구속 시키고\n이익 토해내라',
#  '한국정부는 택시감차정책중인데 어느4차원나라와 한국이합병을했는지요 설사 합병시에는 전기차로하든지 경유차로 그것도 엉터리조항을 맞춘다고 11인승에 1사람타면 법에 어울린다네 기가막힌다 차라리 환경이라도지켜라 불법은 이미 만연해졌다고 하더라도\n먼 후손을 조금이라도 위한다면 우째 바이러스까지 들어오겠나ㅡ나라를 아작낸다고밖에는 생각이 안들지요?',
#  '좋은선택이요 매연땜에 아주 죽것소',
#  '재웅씨~날로 쳐먹는거 좋아하면 노량진수산시장으로 가시지요~ㄷ',
#  '이철희.이분.특희.저질이다.그래서.비래대표는.없애야됩니다',
#  '랜터카로 택시영업하는게\n날강도지   무슨개같은  혁신이라  하는겨cb꺼',
#  '당연한것아니냐\n불법인데',
#  '택시 무서워서 못하지 수익이 나지 않으니 타다가 온갓 혜택을 받아야 할수있지',
#  '재웅아 그동안 거져먹었지? 택시영업을 할려면 택시면허 취득해서 기존의 택시 매매해서 영업해라.  어디서 거져먹을라고하냐  렌터카로  택시영업한다는 발상이 잘못된거다  왜?렌터카는 관광목적이거든. 재웅아 너 잘못해도 한참잘못한거야 사죄해라',
#  'https://youtu.be/y8AeHkkIv84',
#  'https://youtu.be/W8NvqsX6jgo\nhttps://youtu.be/NdDlm1pwNaw\n타다기사님들에 대한 안정적인\n노동도 보장안하면서  부자들의\n노예를 만드는......\nhttps://youtu.be/w_qHH-7sisQ',
#  '면허사서 합법적으로 할생각을해야지!!!\n이게4차산업이러면 5차산업은 \n판사,검사,변호사들도 말잘하고 법공부한사람이면 앱으로 호출해서 채용해!!\n의사들도 수의사들 매스만 사용할줄 알면  앱으로 호출해서 고용하면 아주 멋진5차산업이겠다',
#  '이거로  안끝나지 콩밥준비되있다',
#  '렌터카콜택시가무슨혁신인가요 ㆍ 법이제한하면 당연히그만두어야하는게맞지않나요 무얼믿고 엄포야',
#  '초등학생한테물어보는게 좋을듯 이런사업이 4차원인지 요즘 애들은 4차원세계 3차원세계 다 알고있습니다\n언넝 이딴주제로 시간보내지말고 공기를 맑게하는 주제로 범국민적인 대타협을 전개하세요',
#  '그인간타다서비스중단하면내손에장을직갔다.절대서비스포기안한다.지금은동정표사기위한쇼다.두고봐라',
#  '타다 이재웅는 법과 관계없이 오로지 공짜로 하겠다는 심보네~',
#  '타다가 정부가 개입해서 중재할 때 받아들였어야지 이건 대표가 멍청해서 벌어진 결과..ㅉㅉ 돈독이 올라서 스스로 황금알거위 배를 갈랐네',
#  '타다 혼자타다',
#  '부산만 하더라도 택시가 24000대인데\n무분별하게 타다같은 업체가 렌탈카니발 증차해봐라 30000대나 되어서\n온 도로에 택시랑 타다가 교통체증 유발한다.\n그래서 기여금 지출해서 운수사업법에 들어와 차량총량제에 동참하라는데\n돈 내기 싫다고 타다 서비스종료하겠다고 \n국민들 대상으로 얄궃은 협박하는거임',
#  '슬픈 현실',
#  '미래가어둡다.',
#  '타다 감성 팔이 그만해야지 처음부터 합법 적으로 했으면 아쉽다 너무 돈에 목숨걸고 불법을 교묘하게 파고들어 국민 분열시키고 인성 부터 고처야 할것이다',
#  '타다 금지법 잘했네',
#  '불법 이제부터 안 타다!!',
#  '면허사서 합법적으로 할생각을해야지!!!\n이게4차산업이러면 5차산업은 \n판사,검사,변호사들도 말잘하고 법공부한사람이면 앱으로 호출해서 채용해!!\n의사들도 수의사들 매스만 사용할줄 알면  앱으로 호출해서 고용하면 아주 멋진5차산업이겠다',
#  '택시기사 눈치만보고 서울시민 불편은 무시하고 뭐하자는 건지?',
#  '이야 택시기사들이 떼법이네 떼 쓰면 다 들어줌',
#  '신천지와 타다는 사이비다.',
#  '택시기사들 표가 무섭긴한가보다',
#  '타다를 금지한다는데 솔직히 이해가 안된다\n선거철이 코앞인데 이때 금지하는 이유가 뭘까?  뻔하지\n여야 모두 택시 기사들 표가 중요하거든\n\n여론조사에선 택시 기사 욕하는 국민이 7할은 넘었는데 법은 오히려 타다가 문제있다고 한다?\n졸라웃기네',
#  '역시 엠비씨는 댓글부터  걸러야해 ㅋㅋㅋㅋㅋ',
#  '이게무슨 이슈거리인가 불법을 합법처럼 돈에눈이멀어 억어지로 한놈들이 문제지 이슈는 코로나를 코로나온다 라고한 놈이 이슈지',
#  '택시기사한테 차안에서 담배냄새 나서 내가 내렸더니 기사가 나한테 참고 타라더랔ㅋㅋㅋ\n타다가 좋았는데...',
#  '정당하게 노란 영업용넘버달고 장사해 짜샤~어벙해..',
#  '세상을 잔머리굴리며살면결과는정의편에선다는것을 명심해 앞으로살아라',
#  '택시운전자 가족걱정도 해주시고 따듯한 나라네요ㅋㅋㅋㅋㅋㅋㅋ 5년후에 보죠',
#  '불법 편법으로 사업할려고 했으면서 혁신이나 이런식으로 포장하는게 말이 안된다고봅니다.\n택시처럼 운영하면서 랜트카업체라고 끝까지 우기는게 참...',
#  '생긴대로노는구나 언제 나 혁신과 제정신을 구분할런지 안타깝다',
#  '경제폭망 외교폭망 의료보건폭망 통일안보 폭망 어느거하나 제대로하는게 없는 무능저능뭉재앙정권 ㅋㅋ 미국은 우버리프트기업이 창출하는 일자리와 부가가치가 천문학적인데 한국은 아직시작도 못하는 이유 시진봉만도 못한 지도력덕분 ㅋㅋㅋ 문좌빨기업 네이버는 기살려 반문기업 카카오는 기죽어 ㅋㅋㅋㅋ',
#  '세상이.진화하는것을..모르는.구할말시대.양반들.표를의식해서.반대하는것.다알지요.',
#  '모두가,아무나 운수업하면 공급 과잉이고 결국 다 망하는거지 뭐,누구는 초기에 단물만먹고 빠지고',
#  '택시회사입사하세요  택시노는차가 많이 서있는데 기사가 없음 택시자격증 따가지고 오세용 바로입사 택시회사에서 대환영합니다',
#  '일자리를 왜자꾸없애는거지',
#  '택시사업면허 택시넘버 정당하게 사서해 \n타다야',
#  '지들때문에 20 만이넘는택시기사와 100만이넘는그가족들이 고통받는것은 생각 않하겠죠? 무슨 타다가 신삽업이라 엉뚱한 소리를 해대는 재웅이 정말싫다 지구를떠나거라~~~',
#  '용역기사 데려다 쓰면서\xa0 무슨 헛소리냐??재웅아? 소가 웃는다.',
#  '하나의기업이정부와기싸움해이기려고 하니 무슨빽이나힘이있나봐요 정부가 힘이없나요 기업빽이 힘이있나요',
#  '총량제 ㆍ 시장경제가 개판 되는걸 알아야지  대기업들 덤벼들면 차는 막히고   규제가 안되면  개판되는거 뻔한사실',
#  '타다는 사이비 택시다.',
#  '현명하고 옳은선택임. 참 잘했슴.',
#  '법을 어기면서 하면 안되지요',
#  'ㅋㅋㅋ당연한 결과임 문재인 믿고 깝친결과임',
#  '이재웅 생긴대로 복이없군 .. 이철희 기억하겠슴 여상규 화이팅!',
#  '당연한 결과다.',
#  '이재웅 저놈 문재인 빽 믿고 더럽게 설치더니  고소하다^^',
#  '차라리 노란색이란  넘버 없애주세요  법이고 나발이고..',
#  '한국에서 에어비앤비 창업했으면, 동네 모텔이랑 여인숙 살려내라고 시위해서 망했을듯....  나라가 이 모양이니 누가 창업을 하려고 할것이며...  청년 구직자들 모두 공무원 되려고 혈안이지.... 이러니 악순환이 발생할 수 밖에... 진심 한심하고 능력없는 좌파 정권... 저러면서 주댕이로는 4차 산업혁명...  과연 문재앙이 4차 산업혁명을 이해하겠냐... 안철수나 유승민 정도나 이해하겠지....',
#  '우리가 돈 더내고 쾌적하고 편한 서비스를 누리고싶다는데 왜 지들이난리야 아 짜증나',
#  '노답이네 국회....',
#  '택시안타ㅡ 하...  짱나.. \n총선앞두고 득표해보겠다는건가? ㅋ  어이상실이네.. \n쩐 담배냄새 시끄러운 라디오소리.. 반려동물데리고 타려면 거부ㅡㅡ\n누가 운전하는건지 신분도 알수없는 택시범죄ㅡㅡ 진짜\n공산주의도아니고 무슨 선택해서 탈 기회도 없애버려 지들은 기사딸린 자차만 타고다니면서',
#  '타다서비스를 응원합니다. 타다는 최소한 텍시들처럼 손님 골라태우기는...',
#  '기사들을 봉으로 아는 타다\n사대보험도 안되고 날마다 보험료 뜯어가는 타다 \n운행중단한다고 배차도 줄이고  드라이버들이 어떻게 되든 신경도 안쓰는 \n타다  실망이다\n콜택시지 무슨 렌터카냐',
#  '멍멍멍',
#  '희대의사기꾼...',
#  '타다 금지 시켜서 좋아 했지? 이젠 너희들이 쫓겨 나게 될거야',
#  '신천지와 타다는 사회를 좀 먹는 사이비다.',
#  '타다 베이직은 종료하고. 공항이랑 프라이빗렌트 서비스는 합법이니 계속하겠는데요',
#  '혁신 같은 소리는  무슨 그냥 렌트카 호출이지  우리나라 택시 남아돈다',
#  '타다만 빼고  다른 업체는 충분히 할수잇다 카카오는 바보라 투자햇나  꽁짜로 쳐묵을려니까 문제지',
#  '타다뺀 다른 스타트업계에서 국회통과 요구하고 성명서까지 냈는데 뭔 개소리인지...이재웅이 똘마니기자인가?',
#  '타다헛소리',
#  '진정 1만명 드라이버 때문인겨?ㅎ',
#  '1만명의 직원 = 외부아웃소싱',
#  '지금은 코로나 사태로 택시잡기가 쉬워졌지만, 대구 터지기 직전만 해도 택시 잡기 너무 어려웠다. 타다를 이용해본적은 없으나, 택시 대체상품이 어느정도는 있길 바란다. 국회에서 저 법이 부결되어 계속 타다를 이용할 수 있었으면 한다.',
#  '부산만 하더라도 택시가 24000대인데\n무분별하게 타다같은 업체가 렌탈카니발 증차해봐라 30000대나 되어서\n온 도로에 택시랑 타다가 교통체증 유발한다.\n그래서 기여금 지출해서 운수사업법에 들어와 차량총량제에 동참하라는데\n돈 내기 싫다고 타가 서비스종료하겠다고\n국민들 대상으로 얄궃은 협박하는거임',
#  '혁신은 면죄부가 아닙니다. 국회를 왜 설득하지 못했는지 곰곰 생각해보면 답이 나옵니다. 여야가 전혀 이견이 없었습니다. 국회의원이 다 바보입니까? 후배 볼 면목이 없다고 하는데 후발 경쟁업체들 모두 이번 법안에 찬성했습니다. 자세한 내막을 모르는 국민을 상대로 피해자 코스프레해봐야 더 얻는 것은 없을 겁니다.',
#  '전국민의 렌트카 기사화ᆢ ㅎㅎ',
#  '신천지와 타다는 짝퉁이다!',
#  '또다른 택시영업 말장난하지말고 방법을 찾아봐라',
#  '이재웅이를 구속하라!',
#  '타다는 좌파정권의 졸작품 . 국가 질서에 위배  더이상 떠덜지 마라. 기사님 분신의 얼을 위로하며.',
#  '니들은 거짓말 쟁이 기업형 사깃꾼들이다\n왜 개인 불법택시영업이 4차산업이고 혁신산업이고 공유경제냐?\n개인이 하면 안되고 니들이 하면 되는거냐 이사깃꾸늘아',
#  '택시는 싫다고 하고\n국가는 안된다고 하는데\n국민은 좋다고 하네..',
#  '범법을 넘어 범죄집단이다',
#  '면허사서 합법적으로 할생각을해야지!!!\n이게4차산업이러면 5차산업은 \n판사,검사,변호사들도 말잘하고 법공부한사람이면 앱으로 호출해서 채용해!!\n의사들도 수의사들 매스만 사용할줄 알면  앱으로 호출해서 고용하면 아주 멋진5차산업이겠다',
#  'ㅋㅋㅋ 있으나 마나한 문재인이 참 도와주겠다? 글이라도 잃어주면 다행으로 여겨라',
#  '혁신도 아니고, 제도권도 아니고, 그냥 둘다 아닙니다.',
#  '꼼수로 영업용 번호판을 부여 받지 않고  여객운송사업을 \n시작하겠다는건 사업자등록후 자가용으로 일반인이 \n문자로 콜 받고 운송 영업활동을 해도 된다는것과 마찬가지의 의미로 생각되어지네요. 이렇게되면 탈세도 막을길 없고 특수 범죄 발생 가능성도 높아질 테고 기존 영업자의 손해는 어떻게 보상 하실런지요~?\n그보다 정상적으로 여객운송 업체의 지분을 확보하고 소속된\n영업용 차량 수 만큼 원하는 차량으로 대체하고\n기존 택시 업계와 다른 님들이 추구하는 월등한 서비스를 제공하세요. 사납금으로 200만원 남짓 손에 쥐는 기사님들 힘들게하지말고요~ 영업용차량은 자가용에 비해 보험료 및 기타 유지 비용이 많이 들고 일반 보험사에 보험가입이 어렵습니다. 그래서 공제 조합에 가입하는겁니다. 일반 보험사에서 종합보험과 자차 가입시 100만원이 지출 된다면\n
#  '불법콜택시 타다 면허ㆍ자격증 갖고하면 될껄 꽁짜로 꿀꺽 하려니까 문제지 사기꾼 이재웅',
#  '용역기사 데려다 쓰면서 기사걱정하냐??소가 웃는다.',
#  '어떡하냐....',
#  '정의는 죽지않았다',
#  '회사 사납금에 대해선 찍소리도 못하는 택시 기사들.',
#  '불법콜택시 타다 면허ㆍ자격증 갖고하면 될껄 꽁짜로 쳐묵을려는 사기꾼',
#  '렌터카로 택시영업하는 사이비...',
#  '대통령  거부건 은  이럴때  쓰라고  만든법  아냠 마',
#  '유튜브가 있어서 다행입니다. 화이팅',
#  '진행자 갓준희님 일단 좋아요 누릅니다',
#  '넓은 시각에서 제대로 현실파악을 하고 있는 발언자들이네요.\n다만 검은자켓 입은 분은, 너무 신자유주의시장경제에 쩔어있네요',
#  '타다는 참 어려운 주제인거 같은데 그나마 갓주니가 풀어줘서 좀 더 잘 이해를 하게 되는 거 같네요.',
#  '타다가 1년반동안 누적적자 300억이라면 택시 밀어낸 후 결국 요금인상으로 이어지겠네',
#  '패널선택이불공편하네요\n타다옹호하려구나왔나\n케이비에스가 타다살려주려구\n토론주제를선택한것같네요\n찬성반대공평한토론자들이필요한것아닌가요 불법은불법인거죠 한의사자격없이침잘놓으면앱만들어서비스하면공유인가요?',
#  '박정희군사쿠데타, 전두환군사쿠데타국민학살, 박그네세월호 최서원 국정농단 최태민과 이마니 사이비를 옹호, 지지, 계승한다고 나팔부는 친일매국의 한둥지 새누리 미똥, \n코로나감염방지를 위해 시설목록과 교도명단, 접촉자명단을 내라고 해도 계속 거짓을 제출하는 이마니를 신천지, 사이비, 바이오테러집단의 수괴라 부르지 못하고 정치적 연대, 비호, 보호를 하는 집단인 빤사 개검과 새누리미똥. \n415 민주 진보에 몰표, 최소 181석, 바이러스 탄핵 박멸.',
#  '그냥 개인 자격으로 참여한 분들로 봅시다.\n여튼 패널 선정은.완전 에러',
#  '타다 서비스를 응원합니다.텍시업계 고질적인 관행과 독재를 이번에 바꿔야된다 사료됩니다. 첫째 손님골라태우기. 둘째. 불법주정차. 셋째. 어슬렁거리며 손님 찾아다니느라 뒤차들까지 속도 못내게해 도심 교통채증 야기시키는 텍시기사들. 넷째. 뻔히 가는길 다 아는데 돌아가서 바가지요금 빨아먹는 쓰레기텍시. 물론 텍시 입장에선 내차로 내 맘데로 하겠다는데 니들이 뭔 간섭이야 하겠지만 시민들 입장에선 타다 서비스가 더 적합하다 사료됩니다...',
#  '택사  노조댓글부대 ㅋㅋㅋㅋㅋ  왜 ㅋㅋㅋ  소비자들은  ㅋㅋ  찬성하는데   노조및  표를   의식하는   국회는   반대하냐 ㅋㅋㅋ',
#  '타다가 합법이면  인터넷 도박싸이트도  합법이다.\n도독놈  씸뽀다      타다  타다   영윈히  불타다\n하루빨리  영원히  사라져야  된다.\n곧바로  ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
#  '불법 타다 해동대원들어디로가나?',
#  '타다 금지 시켜서 좋아 했지? 이젠 너희들이 쫓겨나게 될거야',
#  '타다 서비스를 응원 합니다...타다는 최소한 텍시들처럼 손님 골라태우지는...텍시는 불법주.정차나 손님찾아 어슬렁데며 운전해 도심 교통채증 만들기나 뻔히 가는길 아는데 돌아가 바가지요금 빨아먹거나.국회의원 여러분들께 진심으로 바랍니다 선거 끝나면 텍시업계 정리좀...시민들 입장에선 타다서비스가 더 적합 합니다. 의원님들도 한번 타보세요...',
#  '채이배,이철희 타다다 혁신이면 대한민국 기업 전체가 혁신일것이다 이철희는 불출마라 다행 채이배는 자넨 21대에 여의도근처 절대 못올것이다 여상규 법사위원장 감사합니다 멋져부러~^^',
#  '이철희   너 같은게  국회의원이었으니  우리나라가 썩어 빠진거야   출마안한게  천만 다행이다',
#  '채이배 이철희  타다가 불법아니냐?  법좀제대로 알고 국회의원해라  당신들 이번이 마지막이지?',
#  '뭘더 토론할게 있냐 지금의 타다는 불법이다  면허도없는 사실상택시가 어디있냐. 랜터카에 맞은 영업을 하라는것이 이법이다']

# %%
#NLP 분석 시 텍스트 형태로 불러와 작업해줘야 함.(파일 쓰는 함수)
def write_txt(list,fname,sep):
    file = open(fname,'w')
    vstr = ''
    
    for a in list:
        vstr = vstr + str(a) + sep
    vstr = vstr.rstrip(sep)
    
    file.writelines(vstr)
    
    file.close()
    print('[complete]')

# %%
write_txt(comment_sample,'wtest_samlpe.txt',sep="'")

com_txt = open('wtest_samlpe.txt').read()

# 추출된 단어 확인
word_ext = okt.nouns(com_txt)
print(word_ext)
# Out:
# [complete]
# ['인간', '대통령', '등', '별', '회', '괴한', '짓거리', '노블', '리스', '블', '리제', '넌', '도덕', '양심', '낫', '돈', '괴물', '법앞', '만인', '걸', '권력', '기생충', '혁신', '지금', '택시', '회사', '개인', '택시', '줄', '도산', '위기', '머', '자가용', '영업', '이재용', '대표', '말씀', '운수업', '지금', '당장', '택시', '회사', '개인', '택시', '사', '가지', '정상', '운영', '왜', '돈', '푼', '안', '공짜', '반발', '이재용', '대표', '목적', '압니', '말장난', '수천', '만대', '택시', '대기', '중', '인대', '계속', '대기', '당신', '번호판', '차', '차', '택시', '서비스', '개선', '수칙', '나', '내', '택시', '이용', '승객', '내', '이용', '생각', '반대', '입장', '운행', '내', '영업', '구역', '외', '합법', '승차', '거부', '내', '택시', '항상', '청결', '유지', '최대한', '얼굴', '승객', '대한', '승객', '짐', '내', '인사말', '외', '최대한', '말', '카드', '계산', '내', '택시', '운행', '수', '도로', '무조건', '절대', '운행', '중', '전화', '사양', '과속', '및', '난폭운전', '준법', '운행', '용모', '단정', '절대', '영업', '구역', '내', '승차', '거부', '승객', '반말', '등등', '수칙', '정', '사항', '더', '듯', '택시', '서비스', '개선', '답임', '동참', '해', '나가시', '동료', '선', '후배', '이제', '시작', '우리', '업', '보호', '위', '모습', '파이팅', '하나', '접목', '택시', '워', '혁신', '거지', '택시', '평점', '제', '도입', '국민', '청원', '아래', '링크', '대한민
3, '아래': 3, '연구': 3, '스타트': 3, '다야': 3, '대당': 3, '달': 3, '생계': 3, '어찌': 3, '누구': 3, '문': 3, '게': 3, '구입': 3, '값': 3, '예전': 3, '공산': 3, '보고': 3, '편집': 3, '외국': 3, '자체': 3, '전통': 3, '볼': 3, '비용': 3, '감소': 3, '늘': 3, '개입': 3, '버스': 3, '무시': 3, '위반': 3, '기본': 3, '개택': 3, '타고': 3, '정도': 3, '이의': 3, '운전자': 3, '투표': 3, '결정': 3, '뿐': 3, '개무시': 3, '날': 3, '현행법': 3, '그것': 3, '쪽': 3, '누가': 3, '다도': 3, '장난': 3, '해외': 3, '전': 3, '척': 3, '테': 3, '비': 3, '무허가': 3, '종합': 3, '법사': 3, '동네': 3, '재': 3, '탈': 3, '속': 3, '관련': 3, '사업자': 3, '간다': 3, '사실': 3, '꼬': 3, '투자': 3, '공유경제': 3, '만': 3, '형': 3, '사고': 3, '법치국가': 3, '교수': 3, '이완': 3, '안대': 3, '아이템': 3, '간섭': 3, '건': 3, '뒤': 3, '일반': 3, '뉴스': 3, '문제점': 3, '시위': 3, '안보': 3, '조건': 3, '무엇': 3, '바로': 3, '판단': 3, '보도': 3, '정 ...

# %%
#명사, 조사 각 품사들 찾아내기
okt.pos(com_txt, join=True)
# Out:
# ['멍청한/Adjective',
#  '인간/Noun',
#  '!/Punctuation',
#  '대통령/Noun',
#  '등/Noun',
#  '에/Josa',
#  '업고/Verb',
#  '별/Noun',
#  '회/Noun',
#  '괴한/Noun',
#  '짓거리/Noun',
#  '를/Josa',
#  '다/Adverb',
#  '하는구나/Verb',
#  './Punctuation',
#  '노블/Noun',
#  '리스/Noun',
#  '오/Modifier',
#  '블/Noun',
#  '리제/Noun',
#  '!/Punctuation',
#  '넌/Noun',
#  '도덕/Noun',
#  '심도/Verb',
#  '양심/Noun',
#  '도/Josa',
#  '없는/Adjective',
#  '한/Determiner',
#  '낫/Noun',
#  '돈/Noun',
#  '많은/Adjective',
#  '괴물/Noun',
#  '이야/Josa',
#  "~'/Punctuation",
#  '법앞/Noun',
#  '에는/Josa',
#  '만인/Noun',
#  '이/Josa',
#  '평등한/Adjective',
#  '걸/Noun',
#  '알아아지/Verb',
#  '.../Punctuation',
#  '권력/Noun',
#  '기생충/Noun',
#  '들/Suffix',
#  "...'/Punctuation",
#  '혁신/Noun',
#  'ㅡ/KoreanParticle',
#  '지금/Noun',
#  '도/Josa',
#  '택시/Noun',
#  '회사/Noun',
#  '나/Josa',
#  '\n/Foreign',
#  '개인/Noun',
#  '택시/Noun',
#  'ㅡ/KoreanParticle',
#  '줄/Noun',
#  '도산/Noun',
#  '위기/Noun',
#  'ㅡ/KoreanParticle',
#  '\n/Foreign',
#  '타다/Verb',
#  'ㅡ/KoreanParticle',
#  '머/Noun',
#  '여/Josa',
#  'ㅡ/KoreanParticle',
#  '자가용/Noun',
#  '영업/Noun',
#  '까지/Josa',
#  '한다고/Verb',
#  '?/Punctuation',
#  'ㅡ/KoreanParticle',
#  '\n/Foreign',
#  '같이/Adverb',
#  '죽자고/Verb',
#  "?'/Punctuation",
#  '이재용/Noun',
#  '대표/Noun',
#  '님/Suffix',
#  '에게/Josa',
#  '한/Verb',
#  '말씀/Noun',
#  '하겠습니다/Verb',
#  '그렇게/Adverb',
#  '운수업/Noun',
#  '을/Josa',
#  '하고/Verb',
#  '싶으면/Verb',
#  '지금/Noun',
#  '당장/Noun',
#  '택시/Noun',
#  '회사/Noun',
#  '나/Josa',
#  '개인/Noun',
#  '택시/Noun',
#  '면/Josa',
#  '허을/Verb',
#  '사/Noun',
#  '가지/Noun',
#  '고/Josa',
#  '그렇게/Adverb',
#  '정상/Noun',
#  '적/Suffix',
#  '으로/Josa',
#  '운영/Noun',
#  '을/Josa',
#  '하세요/Verb',
#  '왜/Noun',
#  '돈/Noun',
#  '한/Determiner',
#  '푼/Noun',
#  '안/Noun',
#  '들이고/Verb',
#  '그렇게/Adverb',
#  '공짜/Noun',
#  '로/Josa',
#  '하려고/Verb',
#  '그러니까/Adverb',
#  '반발/Noun',
#  '이/Josa',
#  '심한거/Adjective',
#  '아닙니까/Adjective',
#  '~/Punctuation',
#  '\n/Foreign',
#  '이재용/Noun',
#  '대표/Noun',
#  '님/Suffix',
#  '에/Josa',
#  '목적/Noun',
#  '은/Josa',
#  '다른대/Adjective',
#  '있는거다/Adjective',
#  '압니/Noun',
#  '다/Josa',
#  "'/Punctuation",
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ/KoreanParticle',
#  "'/Punctuation",
#  '당연한거다/Adjective',
#  '어디서/Adverb',
#  '말장난/Noun',
#  '으로/Josa',
#  '사가지/Verb',
#  '없이/Adverb',
#  "'/Punctuation",
#  '수천/Noun',
#  '수/Modifier',
#  '만대/Noun',
#  '택시/Noun',
#  '가/Josa',
#  '대기/Noun',
#  '\n/Foreign',
#  '중/Noun',
#  '인대/Noun',
#  '\n/Foreign',
#  '계속/Noun',
#  '대기/Noun',
#  '하고/Verb',
#  '있을까/Adjective',
#  '\n/Foreign',
#  '타다/Verb',
#  '당신/Noun',
#  '도/Josa',
#  '번호판/Noun',
#  '4/Number',
#  '차/Noun',
#  '\n/Foreign',
#  '5/Number',
#  '차/Noun',
#  '하면/Verb',
#  "'/Punctuation",
#  '택시/Noun',
#  '서비스/Noun',
#  '개선/Noun',
#  '수칙/Noun',
#  '!/Punctuation',
#  '\n/Foreign',
#  '나/Noun',
#  '는/Josa',
#  '내/Noun',
#  '택시/Noun',
#  '를/Josa',
#  '이용/Noun',
#  '하는/Verb',
#  '승객/Noun',
#  '에게/Josa',
#  '내/Noun',
#  '가/Josa',
#  '이용/Noun',
#  '한다는/Modifier',
#  '생각/Noun',
#  '으로/Josa',
#  '반대/Noun',
#  '의/Josa',
#  '입장/Noun',
#  '에서/Josa',
#  '운행/Noun',
#  '한다/Verb',
#  '!!/Punctuation',
#  '\n\n/Foreign',
#  '1/Number',
#  './Punctuation',
#  '내/Noun',
#  '영업/Noun',
#  '구역/Noun',
#  '외/Noun',
#  '가급적/Adverb',
#  '합법/Noun',
#  '승차/Noun',
#  '거부/Noun',
#  '도/Josa',
#  '줄인다/Verb',
#  '\n/Foreign',
#  '2/Number',
#  './Punctuation',
#  '내/Noun',
#  '택시/Noun',
#  '는/Josa',
#  '항상/Noun',
#  '청결/Noun',
#  '을/Josa',
#  '유지/Noun',
#  '한다/Verb',
#  '\n/Foreign',
#  '3/Number',
#  './Punctuation',
#  '익숙하진/Adjective',
#  '않지만/Verb',
#  "'/Punctuation",
#  '안녕하세요/Adjective',
#  "','/Punctuation",
#  '감사합니다/Verb',
#  "'/Punctuation",
#  '\n   /Foreign',
#  '최대한/Noun',
#  '웃는/Verb',
#  '얼굴/Noun',
#  '로/Josa',
#  '승객/Noun',
#  '을/Josa',
#  '대한/Noun',
#  '다/Adverb',
#  '\n/Foreign',
#  '4/Number',
#  './Punctuation',
#  '승객/Noun',
#  '의/Josa',
#  '짐/Noun',
#  '은/Josa',
#  '내/Noun',
#  '가/Josa',
#  '싣고/Verb',
#  '내려/Verb',
#  '드린다/Verb',
#  '\n/Foreign',
#  '5/Number',
#  './Punctuation',
#  '인사말/Noun',
#  '외/Noun',
#  '최대한/Noun',
#  '말/Noun',
#  '을/Josa',
#  '줄인다/Verb',
#  '\n/Foreign',
#  '6/Number',
#  './Punctuation',
#  '카드/Noun',
#  '계산/Noun',
#  '도/Josa',
#  '반갑게/Adjective',
#  '받아/Verb',
#  '들인다/Verb',
#  '\n/Foreign',
#  '7/Number',
#  './Punctuation',
#  '내/Noun',
#  '택시/Noun',
#  '가/Josa',
#  '운행/Noun',
#  '할/Verb',
#  '수/Noun',
#  '있는/Adjective',
#  '도로/Noun',
#  '는/Josa',
#  '무조건/Noun',
#  '\n   /Foreign',
#  '모신다/Verb',
#  '\n/Foreign',
#  '8/Number',
#  './Punctuation',
#  '절대/Noun',
#  '운행/Noun',
#  '중/Noun',
#  '전화/Noun',
#  '는/Josa',
#  '사양/Noun',
#  '한/Josa',
#  '다/Adverb',
#  '\n/Foreign',
#  '9/Number',
#  './Punctuation',
#  '과속/Noun',
#  '및/Noun',
#  '난폭운전/Noun',
#  'NO/Alpha',
#  '준법/Noun',
#  '운행/Noun',
#  '한다/Verb',
#  '\n/Foreign',
#  '10/Number',
#  './Punctuation',
#  '용모/Noun',
#  '단정/Noun',
#  '!/Punctuation',
#  '\n/Foreign',
#  '11/Number',
#  './Punctuation',
#  '절대/Noun',
#  '영업/Noun',
#  '구역/Noun',
#  '내/Noun',
#  '승차/Noun',
#  '거부/Noun',
#  '는/Josa',
#  '없다/Adjective',
#  '\n/Foreign',
#  '12/Number',
#  './Punctuation',
#  '젊은/Adjective',
#  '승객/Noun',
#  '에게/Josa',
#  '반말/Noun',
#  '하지/Verb',
#  '않기/Verb',
#  '\n\n/Foreign',
#  '등등/Noun',
#  '수칙/Noun',
#  '으로/Josa',
#  '정/Noun',
#  '할/Verb',
#  '사항/Noun',
#  '이/Josa',
#  '더/Noun',
#  '있을/Adjective',
#  '듯/Noun',
#  '합니다/Verb',
#  '\n/Foreign',
#  '택시/Noun',
#  '서비스/Noun',
#  '개선/Noun',
#  '만이/Josa',
#  '답임/Noun',
#  '을/Josa',
#  '동참/Noun',
#  '해/Noun',
#  '나가시/Noun',
#  '죠/Josa',
#  '\n/Foreign',
#  '동료/Noun',
#  '선/Noun',
#  ',/Punctuation',
#  '후배/Noun',
#  '님/Suffix',
#  '들/Verb',
#  '이제/Noun',
#  '부터/Josa',
#  '시작/Noun',
#  '입니다/Adjective',
#  '!/Punctuation',
#  '\n/Foreign',
#  '우리/Noun',
#  '업/Noun',
#  '권/Suffix',
#  '보호/Noun',
#  '를/Josa',
#  '위/Noun',
#  '한/Josa',
#  '모습/Noun',
#  '!!/Punctuation',
#  '파이팅/Noun',
#  '입니다/Adjective',
#  "'/Punctuation",
#  'it/Alpha',
#  '하나/Noun',
#  '접목/Noun',
#  '시킨거/Verb',
#  '빼고는/Verb',
#  '택시/Noun',
#  '랑/Josa',
#  '다를게/Adjective',
#  '없는데/Adjective',
#  '워/Noun',
#  '가/Josa',
#  '혁신/Noun',
#  '이라는/Josa',
#  '거지/Noun',
#  "?'/Punctuation",
#  '택시/Noun',
#  '평점/Noun',
#  '제/Noun',
#  '도입/Noun',
#  '국민/Noun',
#  '청원/Noun',
#  './Punctuation',
#  '아래/Noun',
#  '링크/Noun',
#  "'/Punctuation",
#  '대한민국/Noun',
#  '자우시/Verb',
#  '장국/Noun',
#  '가/Josa',
#  '맞지/Verb',
#  '?/Punctuation',
#  'ㅋㅋㅋ/KoreanParticle',
#  '택시/Noun',
#  '만/Josa',
#  '경쟁/Noun',
#  '하는/Verb',
#  '모습/Noun',
#  'ㅈ/KoreanParticle',
#  '같노/Adjective',
#  'ㅋㅋ/KoreanParticle',
#  "'/Punctuation",
#  '불법/Noun',
#  '스타트업/Noun',
#  '은/Josa',
#  '안/VerbPrefix',
#  '생겨도/Adjective',
#  '이/Determiner',
#  '세상/Noun',
#  '아주/Noun',
#  '잘/Verb',
#  '돌아가/Verb',
#  './Punctuation',
#  '그런/Modifier',
#  '걱정/Noun',
#  '은/Josa',
#  '안해/Noun',
#  '도/Josa',
#  '돼/Verb',
#  './Punctuation',
#  '세계/Noun',
#  '평화/Noun',
#  '나/Josa',
#  '잘/Verb',
#  '연구/Noun',
#  '해봐/Verb',
#  "'/Punctuation",
#  '멍멍/Adverb',
#  '이/Determiner',
#  '소리/Noun',
#  '하지/Verb',
#  '마시고/Verb',
#  '\n/Foreign',
#  '법/Noun',
#  '안/Noun',
#  '으로/Josa',
#  '들어와/Verb',
#  '\n/Foreign',
#  '날로/Noun',
#  '먹지/Verb',
#  '말고/Josa',
#  "'/Punctuation",
#  '타/Modifier',
#  '다가/Noun',
#  '스타트/Noun',
#  '업/Noun',
#  '이래/Josa',
#  '.../Punctuation',
#  '이재웅/Noun',
#  '아/Josa',
#  '사기치지/Verb',
#  '마라/Adjective',
#  ".'/Punctuation",
#  '택시/Noun',
#  '도/Josa',
#  '너무/Adverb',
#  '많아서/Adjective',
#  '다/Adverb',
#  '서있는데/Verb',
#  "'/Punctuation",
#  '진짜/Noun',
#  '진보/Noun',
#  '적/Suffix',
#  '이지/Josa',
#  '못/VerbPrefix',
#  '하네/Verb',
#  "..'/Punctuation",
#  '불법/Noun',
#  '타/Modifier',
#  '다야/Noun',
#  '잘/Verb',
#  '가라/Noun',
#  "!!!'/Punctuation",
#  '민주주의/Noun',
#  '의/Josa',
#  '후퇴/Noun',
#  '!/Punctuation',
#  '부끄럽다/Adjective',
#  ".'/Punctuation",
#  '렌터카/Noun',
#  '타/Modifier',
#  '다가/Noun',
#  '택시/Noun',
#  '영업/Noun',
#  '하/Suffix',
#  '면/Josa',
#  '안되지/Adjective',
#  "...'/Punctuation",
#  '이재웅/Noun',
#  'ㄲ/KoreanParticle',
#  'ㆍ/Foreign',
#  '시/Noun',
#  '다/Josa',
#  "'/Punctuation",
#  '타다/Verb',
#  '차량/Noun',
#  '이/Josa',
#  '1500/Number',
#  '대인데/Verb',
#  '기사/Noun',
#  '가/Josa',
#  '10000/Number',
#  '명/Noun',
#  '이/Suffix',
#  '면/Josa',
#  '차/Noun',
#  '한/Determiner',
#  '대당/Noun',
#  '10/Number',
#  '명/Noun',
#  '한/Determiner',
#  '달/Noun',
#  '에/Josa',
#  '한/Determiner',
#  '분/Noun',
#  '에/Josa',
#  '기사/Noun',
#  '가/Josa',
#  '3일/Number',
#  '씩나누어서/Foreign',
#  '주말/Noun',
#  '빼고/Verb',
#  '일/Noun',
#  '하는/Verb',
#  '계산/Noun',
#  '이나/Josa',
#  '오는데/Verb',
#  '3일/Number',
#  '일/Noun',
#  '하고/Josa',
#  '생계/Noun',
#  '가/Josa',
#  '걱정/Noun',
#  '입/Noun',
#  '만/Josa',
#  '열면/Verb',
#  '구라/Noun',
#  '야/Josa',
#  "'/Punctuation",
#  '타다/Verb',
#  '1500/Number',
#  '대인데/Verb',
#  '기사/Noun',
#  '가/Josa',
#  '12000/Number',
#  '명/Noun',
#  '이면/Noun',
#  '차/Noun',
#  '한/Josa',
#  '대에/Verb',
#  '기사/Noun',
#  '가/Josa',
#  '10/Number',
#  '명정/Noun',
#  '도/Josa',
#  '라는/Josa',
#  '말인데요/Verb',
#  '말/Noun',
#  '이/Josa',
#  '안/VerbPrefix',
#  '맞아/Verb',
#  '웃기/Noun',
#  '고/Josa',
#  '자빠졌네/Verb',
#  "'/Punctuation",
#  '이재웅/Noun',
#  '을/Josa',
#  '구/Modifier',
#  '속/Modifier',
#  '수아/Noun',
#  '하/Suffix',
#  '라/Josa',
#  "'/Punctuation",
#  '멍멍멍/Noun',
#  '카니발/Noun',
#  '한/Determiner',
#  '대/Modifier',
#  '가져와/Verb',
#  '\n/Foreign',
#  '사줄게/Verb',
#  "'/Punctuation",
#  '나라/Noun',
#  '가/Josa',
#  '어찌/Noun',
#  '해서/Verb',
#  '타다/Verb',
#  '갓/Noun',
#  '은/Josa',
#  '회사/Noun',
#  '한/Determiner',
#  '태/Noun',
#  '후/Noun',
#  '둘리/Noun',
#  '는/Josa',
#  '지/Verb',
#  '이건/Noun',
#  '말/Noun',
#  '두/Josa',
#  '안되는/Adjective',
#  '사업/Noun',
#  '이지/Josa',
#  "'/Punctuation",
#  '타다/Verb',
#  '너무/Adverb',
#  '양심/Noun',
#  '없었지/Adjective',
#  "'/Punctuation",
#  '불법/Noun',
#  '콜/Noun',
#  '뛰/Verb',
#  '기는/Verb',
#  '죄/Noun',
#  '를/Josa',
#  '받아라/Verb',
#  "'/Punctuation",
#  '불법/Noun',
#  '은/Josa',
#  '사라져야죠/Verb',
#  "!'/Punctuation",
#  '누구/Noun',
#  '닮아/Verb',
#  '양/Modifier',
#  '아치/Noun',
#  '짓거리/Noun',
#  '만/Josa',
#  '하드/Noun',
#  '만/Josa',
#  '잘/VerbPrefix',
#  '됐다/Verb',
#  './Punctuation',
#  '노블/Noun',
#  '리스/Noun',
#  '오/Modifier',
#  '블/Noun',
#  '리제/Noun',
#  '!/Punctuation',
#  '양/Modifier',
#  '아치/Noun',
#  '가/Josa',
#  '돈/Noun',
#  '많으면/Adjective',
#  '이렇게/Adverb',
#  '됩니다/Verb',
#  './Punctuation',
#  '거기/Noun',
#  '다/Josa',
#  '대통령/Noun',
#  '과도/Josa',
#  '유착/Noun',
#  '됐죠/Verb',
#  "?'/Punctuation",
#  '이/Determiner',
#  '제/Modifier',
#  '웅/Noun',
#  '대표/Noun',
#  '사기꾼/Noun',
#  "'/Punctuation",
#  '타/Modifier',
#  '다운/Noun',
#  '전자법/Noun',
#  '인/Josa',
#  '택시/Noun',
#  '일자리/Noun',
#  '엄청나다/Adjective',
#  "'/Punctuation",
#  '국난/Noun',
#  '을/Josa',
#  '불감/Noun',
#  '하는/Verb',
#  '국회/Noun',
#  '!/Punctuation',
#  '개/Noun',
#  '!/Punctuation',
#  '악/Noun',
#  '법/Noun',
#  '의/Josa',
#  '독재/Noun',
#  '자/Noun',
#  '!/Punctuation',
#  '문/Noun',
#  '재인/Noun',
#  '!/Punctuation',
#  '!/Punctuation',
#  '속히/Adverb',
#  '파면/Noun',
#  '하라/Noun',
#  "!!!'/Punctuation",
#  '합법/Noun',
#  '좋아하시네/Adjective',
#  "'/Punctuation",
#  '신천지/Noun',
#  '와/Josa',
#  '타다는/Verb',
#  '사회/Noun',
#  '를/Josa',
#  '좀/Noun',
#  '먹는/Verb',
#  '사이비/Noun',
#  '다/Josa',
#  ".'/Punctuation",
#  '이/Determiner',
#  '게/Noun',
#  '나라/Suffix',
#  '냐/Josa',
#  '?/Punctuation',
#  '부정/Noun',
#  '도/Josa',
#  '나라/Noun',
#  '가/Josa',
#  '정당화/Noun',
#  '시켜주나/Verb',
#  "~!'/Punctuation",
#  '택시/Noun',
#  '도/Josa',
#  '카니발/Noun',
#  '스타렉스/Noun',
#  '\n/Foreign',
#  '차량/Noun',
#  '다변/Noun',
#  '화/Suffix',
#  '가/Josa',
#  '되/Verb',
#  '야할것/Adjective',
#  '같네요/Adjective',
#  "'/Punctuation",
#  '언론/Noun',
#  '을/Josa',
#  '장학/Noun',
#  '한/Josa',
#  '정부/Noun',
#  '법도/Noun',
#  '없는/Adjective',
#  '정부/Noun',
#  '여론몰이/Noun',
#  '선수/Noun',
#  '나라/Noun',
#  '를/Josa',
#  '홀/Noun',
#  '난하게하는/Adjective',
#  '정부/Noun',
#  "'/Punctuation",
#  '타다/Verb',
#  '기사/Noun',
#  '?/Punctuation',
#  '\n/Foreign',
#  '택시/Noun',
#  '영업/Noun',
#  '안되서/Adjective',
#  'ㅡ/KoreanParticle',
#  '그냥/Noun',
#  '회사/Noun',
#  '에/Josa',
#  '입고/Verb',
#  '되어있는/Verb',
#  '택시/Noun',
#  '\n/Foreign',
#  '무지/Noun',
#  '마너/Noun',
#  '요/Josa',
#  'ㅡ/KoreanParticle',
#  '택시/Noun',
#  '하면되/Verb',
#  '지/Verb',
#  './Punctuation',
#  '왜/Noun',
#  '타/Modifier',
#  '다야/Noun',
#  '.?/Punctuation',
#  'ㅡ/KoreanParticle',
#  '\n/Foreign',
#  '혁신/Noun',
#  '모빌리티/Noun',
#  'ㅡ/KoreanParticle',
#  '다/Noun',
#  '같이/Josa',
#  '\n/Foreign',
#  '죽자고/Verb',
#  '하는/Verb',
#  '짓거리/Noun',
#  ".'/Punctuation",
#  '라이/Noun',
#  '센서/Noun',
#  '를/Josa',
#  '구입/Noun',
#  '해서/Verb',
#  '정정당당하게/Adjective',
#  '해주세요/Verb',
#  "!!!!'/Punctuation",
#  '타다는/Verb',
#  '나중/Noun',
#  '에/Josa',
#  '딱지/Noun',
#  '값/Noun',
#  '챙기려/Verb',
#  '한/Verb',
#  '사업/Noun',
#  '이다/Josa',
#  '../Punctuation',
#  '1500/Number',
#  '대면/Noun',
#  '대당/Noun',
#  '1억만/Number',
#  '되도/Verb',
#  '1500억/Number',
#  '이네/Josa',
#  '../Punctuation',
#  'ㅎㅎ/KoreanParticle',
#  "'/Punctuation",
#  '입법/Noun',
#  '하는/Verb',
#  '사람/Noun',
#  '이/Josa',
#  '합법/Noun',
#  '불법/Noun',
#  '을/Josa',
#  '구분/Noun',
#  '할줄/Verb',
#  '모르니/Verb',
#  '양심/Noun',
#  '은/Josa',
#  '있나/Adjective',
#  '봐/Verb',
#  '\n/Foreign',
#  '불출/Noun',
#  '마한/Noun',
#  '다/Adverb',
#  '고/Noun',
#  '했으니/Verb',
#  "'/Punctuation",
#  '표결/Noun',
#  '없이/Adverb',
#  '통과/Noun',
#  '하는게/Verb',
#  '전례/Noun',
#  '가/Josa',
#  '없어야/Adjective',
#  '하는거/Verb',
#  '아니예요/Adjective',
#  '??/Punctuation',
#  '제/Noun',
#  '가/Josa',
#  '이상한/Adjective',
#  '건가/Noun',
#  "??'/Punctuation",
#  'ㅋㅋㅋㅋㅋㅋㅋ/KoreanParticle',
#  '원래/Noun',
#  '그랬대/Adjective',
#  "'/Punctuation",
#  '예전/Noun',
#  '세녹스/Noun',
#  '=/Punctuation',
#  '휘발유/Noun',
#  '가/Josa',
#  '필요없는/Adjective',
#  '자동차/Noun',
#  '연료/Noun',
#  '이/Determiner',
#  '것/Noun',
#  '도/Josa',
#  '정유/Noun',
#  '사의/Noun',
#  '반발/Noun',
#  '로/Josa',
#  '쭁/Noun',
#  ".......'/Punctuation",
#  '0:50/Number',
#  "'/Punctuation",
#  '프사/Noun',
#  '\n/Foreign',
#  '대한민국/Noun',
#  '우한/Noun',
#  '폐럼/Noun',
#  '걸려/Verb',
#  '뒤졌습니다/Verb',
#  "'/Punctuation",
#  '공산/Noun',
#  '독재/Noun',
#  '네/Josa',
#  "!!!'/Punctuation",
#  '둘달/Noun',
#  '밥맛/Noun',
#  "'/Punctuation",
#  '공/Modifier',
#  '수/Modifier',
#  '처법때/Noun',
#  '문희상/Noun',
#  '보고/Noun',
#  '국민/Noun',
#  '들/Suffix',
#  '맘/Noun',
#  '이/Josa',
#  '어땟는/Noun',
#  '지/Josa',
#  '이제/Noun',
#  '알겠냐/Verb',
#  "?'/Punctuation",
#  '편집/Noun',
#  '을/Josa',
#  '웃기/Noun',
#  '게/Josa',
#  '했네/Verb',
#  "'/Punctuation",
#  '이야/Josa',
#  '북한/Noun',
#  '이야/Josa',
#  '?/Punctuation',
#  'ㅋㅋㅋㅋ/KoreanParticle',
#  '그렇게/Adverb',
#  '북한/Noun',
#  '욕/Noun',
#  '하면서/Verb',
#  '하는/Verb',
#  '짓은/Verb',
#  '김정은/Noun',
#  '이네/Josa',
#  'ㅋㅋㅋㅋㅋ/KoreanParticle',
#  '갓/Modifier',
#  '상규/Noun',
#  "'/Punctuation",
#  '겁나/Verb',
#  '멋있어/Adjective',
#  './Punctuation',
#  'ㅎㅎㅎ/KoreanParticle',
#  "'/Punctuation",
#  '여객/Noun',
#  '자동차/Noun',
#  '운수/Noun',
#  '사업/Noun',
#  '법/Noun',
#  ',/Punctuation',
#  '운전/Noun',
#  '을/Josa',
#  '생계/Noun',
#  '로/Josa',
#  '하시는/Verb',
#  '특히/Adverb',
#  '택시/Noun',
#  '기사/Noun',
#  '님/Suffix',
#  '들/Verb',
#  '운전/Noun',
#  '이/Josa',
#  '도로/Noun',
#  '상의/Noun',
#  '흉기/Noun',
#  '로/Josa',
#  '변하고있습니다/Adjective',
#  './Punctuation',
#  '이점/Noun',
#  '도/Josa',
#  '법적/Noun',
#  '강화/Noun',
#  '가/Josa',
#  '필요할듯/Adjective',
#  '싶습니다/Verb',
#  './Punctuation',
#  '택시/Noun',
#  '기사/Noun',
#  '님/Suffix',
#  '들/Verb',
#  '제발/Noun',
#  '부탁/Noun',
#  '입니다/Adjective',
#  './Punctuation',
#  '모범/Noun',
#  '운전/Noun',
#  '을/Josa',
#  '보여주세요/Verb',
#  './Punctuation',
#  '외국/Noun',
#  '지인/Noun',
#  '이/Josa',
#  '한국/Noun',
#  '와/Josa',
#  '서/Verb',
#  '하는말이/Verb',
#  '한국/Noun',
#  '의/Josa',
#  '교통/Noun',
#  ...]

# %%
# 형태소 추출 하기. norm 은 문장 정규화 stem 은 어간 추출
print(okt.morphs(com_txt, norm=True))
# Out:
', '법적 강화', '택시기사님들 제발', '택시기사님들 제발 부탁', '모범운전', '외국', '외국 지인', '한국', '한국의 교통문화', '한국의 교통문화 운전', '한국의 교통문화 운전의 악습관', '택시로부터', '보이', '그나', '교통문화', '이말', '자국민', '얼마나', '비현실적', '제발', '제발 부탁', '타인', '타인의 생명', '타인의 생명과 안전', '한번쯤', '한번쯤 생각', '과제', '사람', '언제', '꼴통', '해도', '국민들', '회의', '판사', '판사였을때', '판사였을때 얼마나', '판사였을때 얼마나 억울한 자들', '감옥', '고통', '권위적 그', '권위적 그 자체', '국회의원', '국회의원  올해', '제일', '제일 잘한일', '전통', '여상규', '여상규 저', '여상규 저 사람', '지멋대로', '지멋대로할꺼면 법', '지멋대로할꺼면 법사위는 왜', '절차상', '부산', '24000', '무분별', '같은 업체', '렌탈카니발', '렌탈카니발 증차', '30000', '온 도로', '타다가 교통체증', '타다가 교통체증 유발', '기여금', '기여금 지출', '운수사업법', '차량총량제', '동참하', '돈 내기', '타가', '타가 서비스종료', '국민들 대상', '얄궃', '협박', '타다가 카택', '카택', '최소한', '최소한 국민', '최소한 국민의 안전', '운송영업', '운송영업 면허', '어느나라', '무면허', '운송사업', '허가', '모범택시', '모범택시 카카오택시', '모범택시 카카오택시 블랙택시', '저건금방통과', '이용자', '이용자 입장', '더 편리한 시스템', '발전', '발전하기를 바라지', '그 방식', '문제', '대기업', '서민', '서민의 일자리', '방식때문', '빈부격차', '더욱', '더욱 발생', '이 사회', '계층', '사회', '사회 곳곳', '재벌', '재벌 대기업들', '빨대', '돈의 흐름', '방해', '또 한가지', '또 한가지 단점', '수도권', '아닌 지방', '가정', '가정하면 그', '가정하면 그 택시비용', '그 지역내', '다시', '다시 돈', '소비', '이용하면 비용', '제외', '수익', '본사', '있는 수도권', '따라서', '따라서 이런방식', '따라서 이런방식의 시스템', '지방', '지방의  돈', '지방의  돈의 흐름', '점점', '일자리', '감소', '인구', '부동산', '부동산 값', '반면', '반면 수도권', '증가', '따라서 부동산', '따라서 부동산 값', '이것', '한국의 지역', '한국의 지역 불균형', '한국의 지역 불균형의 모습', '시스템', '개선', '개선시킬때', '개선시킬때 자본주의', '개선시킬때 자본주의 시장논리', '더 큰 부작용', '발생', '발생할 수', '국가', '개입', '공정한 방향', '축하', '정의', '불법콜택시', '그이상', '그이상 그이', '면허', '자격증', '자격증 갖고해', '사기꾼', '카카오', '택 ...

# %%
# 만약 각 줄별로 동일한 단어가 나올 경우 제거 하고 싶을 때
# 라인별로 읽어야 하기 때문에  open -> readline을 쓴다.
com_txt = open('wtest_samlpe.txt').readlines()
duplicate_comment = []

for i in com_txt:
    duplicate_comment1 = kkma.nouns(i)
    for j in range(0,len(duplicate_comment1)):
        duplicate_comment.append(duplicate_comment1[j])
print(duplicate_comment)
# Out:
10), ('때문', 10), ('금지법', 10), ('택시기사', 10), ('경제', 10), ('무죄', 10), ('사서', 10), ('5차산업', 10), ('앱으', 10), ('이용', 9), ('입장', 9), ('렌터카', 9), ('택시영업', 9), ('신천지', 9), ('총량', 9), ('지법', 9), ('4차산업', 9), ('선택', 9), ('개인', 8), ('도로', 8), ('시작', 8), ('자동차', 8), ('의원', 8), ('협박', 8), ('운송', 8), ('사납금', 8), ('이유', 8), ('총선', 8), ('가족', 8), ('영업용', 8), ('정권', 8), ('헌법', 8), ('대표', 7), ('번호판', 7), ('운행', 7), ('동참', 7), ('하나', 7), ('거지', 7), ('스타트', 7), ('세상', 7), ('재인', 7), ('언론', 7), ('증차', 7), ('기여금', 7), ('지출', 7), ('운수사업법', 7), ('종료', 7)]

# %% [markdown]
# #### 워드 클라우드

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()


alice_coloring = np.array(Image.open(path.join(d, 'youtube/car.jpg')))
stopwords = set(STOPWORDS)
stopwords.add("said")

wc = WordCloud(font_path = 'font/D2Coding.ttc', background_color='white',mask=alice_coloring,width=1500, height=1000)
wc.generate_from_frequencies(result_freq_mc_dict) 


image_colors = ImageColorGenerator(alice_coloring, default_color="hot")

plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
figure = plt.gcf() 
figure.set_size_inches(9, 8)
plt.axis('off') 

# 파일 저장 코드
plt.savefig('word_cloud_korea.png',dpi=500)
plt.show()

# %% [markdown]
# #### 단어 별 빈도수 plot

# %%
import nltk 
from nltk.probability import FreqDist 
import matplotlib as mpl

font_location = "font/NanumGothic-Regular.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
matplotlib.rc('font',family = font_name)
plt.figure(figsize=(12,10))
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)

# 두 단어 이상의 글자만 선택한 데이터에서 빈도수 구하고 그려주기
graph_comm = FreqDist(rm_dupl) 
graph_comm.plot(10)

# %% [markdown]
# #### 단어별 네트워크 분석

# %%
from konlpy.tag import Hannanum
import re
import csv
from apyori import apriori
import networkx as nx

# %%
hannanum = Hannanum()

# %%
# 연관성 분석을 위해 댓글별로 단어 쪼개기
dataset = []
for i in range(len(comment_sort)):
    dataset.append(hannanum.nouns(re.sub('[^가-힣a-zA-Z\s]','',comment_sort[i])))
    
test_asso = dataset[:20]
test_asso
# Out:
# [['채이배', '이철희', '불법아니냐', '법좀제대', '국회의원해', '당신들', '이번', '마지막이지'],
#  ['채이배', '이철희', '불법아니냐', '법좀제대', '국회의원해', '당신들', '이번', '마지막이지'],
#  ['이의', '탕탕탕', '개그맨들', '분발', '개콘저리가라'],
#  ['이의', '탕탕탕', '개그맨들', '분발', '개콘저리가라'],
#  ['기업', '편', '손', '미통닭들', '금지', '이유', '신천지', '택시기사들', '표'],
#  ['기업', '편', '손', '미통닭들', '금지', '이유', '신천지', '택시기사들', '표'],
#  ['본질', '팍악하', '계시는거', '박수', '수'],
#  ['본질', '팍악하', '계시는거', '박수', '수'],
#  ['이철희', '너', '뭐냐미친'],
#  ['뭘더', '토론할', '지금', '불법', '면허도', '사실상택시', '어디있냐', '랜터카', '영업', '것', '이법'],
#  ['뭘더', '토론할', '지금', '불법', '면허도', '사실상택시', '어디있냐', '랜터카', '영업', '것', '이법'],
#  ['이철희', '너', '뭐냐미친'],
#  ['마음', '것', '회의', '결정내'],
#  ['오신환의원', '진짜', '국회의원', '검토', '깊이', '대안', '제시', '상황파악', '되있구'],
#  ['채이배이철이이처죽일놈들이래서니놈들이비래대표를잆애야한다는것'],
#  ['채이배이철이이처죽일놈들이래서니놈들이비래대표를잆애야한다는것'],
#  ['뭐', '분명'],
#  ['뭐', '분명'],
#  ['마음', '것', '회의', '결정내'],
#  ['오신환의원', '진짜', '국회의원', '검토', '깊이', '대안', '제시', '상황파악', '되있구']]

# %%
# 연관성분석 명령어, 지지도가 0.01인 것만 가져오기
result = (list(apriori(test_asso, min_support = 0.01)))

# %%
#items가 2개인 것만 선택하기
df = pd.DataFrame(result)
df['length'] = df['items'].apply(lambda x: len(x))
df = df[(df['length'] ==2) & df['support']>=0.1].sort_values(by='support',ascending=False)
df.tail(20)
# Out:
#            items  support                                 ordered_statistics  \
# 104   (미통닭들, 금지)      0.1  [((), (미통닭들, 금지), 0.1, 1.0), ((금지), (미통닭들), 1....
# 105      (손, 금지)      0.1  [((), (손, 금지), 0.1, 1.0), ((금지), (손), 1.0, 10....
# 106    (신천지, 금지)      0.1  [((), (신천지, 금지), 0.1, 1.0), ((금지), (신천지), 1.0,...
# 107     (금지, 이유)      0.1  [((), (금지, 이유), 0.1, 1.0), ((금지), (이유), 1.0, 1...
# 108  (금지, 택시기사들)      0.1  [((), (금지, 택시기사들), 0.1, 1.0), ((금지), (택시기사들), ...
# 109      (편, 금지)      0.1  [((), (편, 금지), 0.1, 1.0), ((금지), (편), 1.0, 10....
# 110      (표, 금지)      0.1  [((), (표, 금지), 0.1, 1.0), ((금지), (표), 1.0, 10....
# 111   (미통닭들, 기업)      0.1  [((), (미통닭들, 기업), 0.1, 1.0), ((기업), (미통닭들), 1....
# 112      (손, 기업)      0.1  [((), (손, 기업), 0.1, 1.0), ((기업), (손), 1.0, 10....
# 113    (신천지, 기업)      0.1  [((), (신천지, 기업), 0.1, 1.0), ((기업), (신천지), 1.0,...
# 114     (이유, 기업)      0.1  [((), (이유, 기업), 0.1, 1.0), ((기업), (이유), 1.0, 1...
# 115  (기업, 택시기사들)      0.1  [((), (기업, 택시기사들), 0.1, 1.0), ((기업), (택시기사들), ...
# 116      (편, 기업)      0.1  [((), (편, 기업), 0.1, 1.0), ((기업), (편), 1.0, 10....
# 117      (표, 기업)      0.1  [((), (표, 기업), 0.1, 1.0), ((기업), (표), 1.0, 10....
# 118     (대안, 깊이)      0.1  [((), (대안, 깊이), 0.1, 1.0), ((깊이), (대안), 1.0, 1...
# 119    (되있구, 깊이)      0.1  [((), (되있구, 깊이), 0.1, 1.0), ((깊이), (되있구), 1.0,...
# 120   (상황파악, 깊이)      0.1  [((), (깊이, 상황파악), 0.1, 1.0), ((깊이), (상황파악), 1....
# 121  (오신환의원, 깊이)      0.1  [((), (오신환의원, 깊이), 0.1, 1.0), ((깊이), (오신환의원), ...
# 122     (제시, 깊이)      0.1  [((), (제시, 깊이), 0.1, 1.0), ((깊이), (제시), 1.0, 1...
# 239       (표, 편)      0.1  [((), (표, 편), 0.1, 1.0), ((편), (표), 1.0, 10.0)...
#
#      length
# 104       2
# 105       2
# 106       2
# 107       2
# 108       2
# 109       2
# 110       2
# 111       2
# 112       2
# 113       2
# 114       2
# 115       2
# 116       2
# 117       2
# 118       2
# 119       2
# 120       2
# 121       2
# 122       2
# 239       2

# %%
# 네트워크 그려주기
G = nx.Graph()
ar=(df['items']); G.add_edges_from(ar)

# %%
pr = nx.pagerank(G)
nsize = np.array([v for v in pr.values()])
nsize = 2000 * (nsize - min(nsize)) / (max(nsize) - min(nsize))

# %%
pos = nx.circular_layout(G)

# %%
plt.figure(figsize=(16,12))
plt.axis('off')
nx.draw_networkx(G, font_family=font_name, font_size=16,
                pos=pos, node_color=list(pr.values()), node_size=nsize,
                alpha = 0.7, edge_color='.5', cmap=plt.cm.YlGn)

# %% [markdown]
# ### 4. 결론

# %% [markdown]
# #### 1) 형태소 분석 결과
# - 예상과 달리, '타다' 단어 언급 빈도가 저조
# - 이유: KoNLPy 패키지에서 '타다'를 동사로 인식하여, 분류 오류 발생.
#  - '타다는' -> '타' + '다는'
#  - '타다' -> '타' + '다'

# %% [markdown]
# #### 2) 워드 클라우드 분석 결과
# - 택시, 불법, 기사, 혁신 등이 많이 언급 되었음.
# - 중간 발표 때, '타다'는 불법이라고 하는 여론과, 혁신적이라고 하는 여론이 양립되어 있을 것으로 예상하였다.
# - 크롤링 개별 영상 댓글에서 유튜브 댓글 트렌드를 확인한 결과, '불법'과 '혁신'이라는 단어의 빈도 수가 높은 것으로 관찰되었다.

# %% [markdown]
# #### 3) 단어 별 네트워크 분석 결과
# - 이철희, 채이배 의원: 언급 빈도가 많고, 두 사람에 대한 연관성이 있는 것으로 보임.
# - 실제로, 두 의원이 주도하여 타다 금지법 법사위 통과 반대한 것으로 확인.

# %% [markdown]
# #### 4) 유튜브 크롤링 시세(티끌모아 태산)

# %%
# %%html
# <iframe src = "https://kmong.com/gig/186921" width="1000px", height ="800px" ;"></iframe>
# Out:
# <iframe src = "https://kmong.com/gig/186921" width="1000px", height ="800px" ;"></iframe>

# %% [markdown]
# ### 5. 보완점

# %% [markdown]
# #### 1) 기술
# - scrapy:
#  - spider.py에서 한 개의 동영상 댓글을 크롤링하면 잘 가져와지나, 여러 개의 링크 동영상을 가져오면 각 링크 별로 일부의 댓글들만 추출되는 문제 확인. 유튜브 api로 1회 크롤링 시 50개의 댓글 제한이 있는데, 이와 유사한 문제로 추측.
# - crontab 설정을 통해 주기적으로 댓글 수집. 댓글 수집 완료되면 메신저로 메시지 보내기.

# %% [markdown]
# #### 2) 분석
#  - 자연어 처리: 특정 단어 인식 문제 발생. 직접 사전 구축하여 처리 필요.
#  - 감성 분석: 긍정/부정, 분류 모델(나이브 베이즈, Dictionary 기반 감성분석) 사용하여 추후 분석 예정.
